# %% [markdown]
# Hey ofac peeps. Here's an example of loading json data into a database (in this case sqlite) via python.
#
# A lot of the ofac data is stored as a nested dictionary, so you'll need to do some stuff iterating through the keys to get what you want/clean the values up, but once you do that uploading it into a database should be very trivial.
#
# Below I explore some data and show a general process of how to insert the data once you've cleaned some of the json up and stuff.

# %%
import dataset
from sqlalchemy.exc import ProgrammingError
import json
import sqlite3

# %%
import sys
print sys.

# %%
# # Set up data base stuff
DB_STRING = "sqlite:///ofac.db"
TABLE_NAME = "ofac"
# Set up data base
db = dataset.connect(DB_STRING)

# %%
conn = sqlite3.connect('ofac.db')

# %%
# the json package has two main methods
# .load() converts json to python (dict or sometimes a list)
# .dump() will 'dump' a dict into json

# we'll use load to load in the json


traffic = json.load(open("OFAC.JSON"))

# If you run `traffic` by itself to view the content it may crash your kernel, heads up 

# traffic
# Out:
# {u'sdnList': {u'_xmlns': u'http://tempuri.org/sdnList.xsd',
#   u'_xmlns:xsi': u'http://www.w3.org/2001/XMLSchema-instance',
#   u'publshInformation': {u'Publish_Date': u'02/16/2017',
#    u'Record_Count': u'5533'},
#   u'sdnEntry': [{u'addressList': {u'address': {u'city': u'Havana',
#       u'country': u'Cuba',
#       u'uid': u'25'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'AERO-CARIBBEAN',
#       u'type': u'a.k.a.',
#       u'uid': u'12'}},
#     u'lastName': u'AEROCARIBBEAN AIRLINES',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'36'},
#    {u'addressList': {u'address': {u'address1': u'Ibex House, The Minories',
#       u'city': u'London',
#       u'country': u'United Kingdom',
#       u'postalCode': u'EC3N 1DY',
#       u'uid': u'129'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'AVIA IMPORT',
#       u'type': u'a.k.a.',
#       u'uid': u'57'}},
#     u'lastName': u'ANGLO-CARIBBEAN CO., LTD.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'173'},
#    {u'addressList': {u'address': [{u'address1': u'Zweierstrasse 35',
#        u'city': u'Zurich',
#        u'country': u'Switzerland',
#        u'postalCode': u'CH-8022',
#        u'uid': u'199'},
#       {u'address1': u'Avenida de Concha Espina 8',
#        u'city': u'Madrid',
#        u'country': u'Spain',
#        u'postalCode': u'E-28036',
#        u'uid': u'200'},
#       {u'address1': u'Dai-Ichi Bldg. 6th Floor, 10-2 Nihombashi, 2-chome, Chuo-ku',
#        u'city': u'Tokyo',
#        u'country': u'Japan',
#        u'postalCode': u'103',
#        u'uid': u'201'},
#       {u'address1': u'Federico Boyd Avenue & 51 Street',
#        u'city': u'Panama City',
#        u'country': u'Panama',
#        u'uid': u'202'}]},
#     u'akaList': {u'aka': [{u'category': u'weak',
#        u'lastName': u'BNC',
#        u'type': u'a.k.a.',
#        u'uid': u'219'},
#       {u'category': u'strong',
#        u'lastName': u'NATIONAL BANK OF CUBA',
#        u'type': u'a.k.a.',
#        u'uid': u'220'}]},
#     u'lastName': u'BANCO NACIONAL DE CUBA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'306'},
#    {u'addressList': {u'address': {u'address1': u'42 Via Brasil',
#       u'city': u'Panama City',
#       u'country': u'Panama',
#       u'uid': u'247'}},
#     u'lastName': u'BOUTIQUE LA MAISON',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'424'},
#    {u'addressList': {u'address': [{u'country': u'Spain', u'uid': u'271'},
#       {u'country': u'Mexico', u'uid': u'272'}]},
#     u'lastName': u'CASA DE CUBA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'475'},
#    {u'addressList': {u'address': {u'city': u'Panama City',
#       u'country': u'Panama',
#       u'uid': u'276'}},
#     u'lastName': u'CECOEX, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'480'},
#    {u'addressList': {u'address': {u'address1': u'Emerson No. 148 Piso 7',
#       u'city': u'Mexico, D.F.',
#       u'country': u'Mexico',
#       u'postalCode': u'11570',
#       u'uid': u'317'}},
#     u'lastName': u'CIMEX',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'535'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'318'}},
#     u'lastName': u'CIMEX IBERICA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'536'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'319'}},
#     u'lastName': u'CIMEX, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'537'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'321'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'COIBA',
#       u'type': u'a.k.a.',
#       u'uid': u'471'}},
#     u'lastName': u'COMERCIAL IBEROAMERICANA, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'540'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'328'}},
#     u'lastName': u'COMERCIAL CIMEX, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'551'},
#    {u'addressList': {u'address': {u'address1': u'Jose Lazaro Galdeano 6-6',
#       u'city': u'Madrid',
#       u'country': u'Spain',
#       u'postalCode': u'28016',
#       u'uid': u'329'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'CRYMSA',
#       u'type': u'a.k.a.',
#       u'uid': u'475'}},
#     u'lastName': u'COMERCIAL DE RODAJES Y MAQUINARIA, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'552'},
#    {u'addressList': {u'address': {u'city': u'Paris',
#       u'country': u'France',
#       u'uid': u'331'}},
#     u'akaList': {u'aka': [{u'category': u'strong',
#        u'lastName': u'COPROVA',
#        u'type': u'a.k.a.',
#        u'uid': u'477'},
#       {u'category': u'strong',
#        u'lastName': u'COPROVA SARL',
#        u'type': u'a.k.a.',
#        u'uid': u'478'}]},
#     u'lastName': u'COMERCIALIZACION DE PRODUCTOS VARIOS',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'555'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'334'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'CIMEX',
#       u'type': u'a.k.a.',
#       u'uid': u'481'}},
#     u'lastName': u'COMPANIA DE IMPORTACION Y EXPORTACION IBERIA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'559'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'346'}},
#     u'lastName': u'CORPORACION CIMEX, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'576'},
#    {u'addressList': {u'address': {u'city': u'Milan',
#       u'country': u'Italy',
#       u'uid': u'348'}},
#     u'lastName': u'COTEI',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'578'},
#    {u'addressList': {u'address': {u'address1': u'Dai-Ichi Bldg. 6th Floor, 10-2 Nihombashi, 2-chome, Chuo-ku',
#       u'city': u'Tokyo',
#       u'country': u'Japan',
#       u'postalCode': u'103',
#       u'uid': u'356'}},
#     u'firstName': u'Juan M. de la',
#     u'lastName': u'CRUZ',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Individual',
#     u'title': u'Director, Banco Nacional de Cuba',
#     u'uid': u'587'},
#    {u'addressList': {u'address': {u'city': u'Buenos Aires',
#       u'country': u'Argentina',
#       u'uid': u'357'}},
#     u'lastName': u'CRYMSA - ARGENTINA, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'589'},
#    {u'addressList': {u'address': {u'city': u'Cancun',
#       u'country': u'Mexico',
#       u'uid': u'358'}},
#     u'lastName': u'CUBACANCUN CIGARS AND GIFT SHOPS',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'590'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'359'}},
#     u'lastName': u'CUBAEXPORT',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'591'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'360'}},
#     u'lastName': u'CUBAFRUTAS',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'592'},
#    {u'addressList': {u'address': {u'country': u'Italy', u'uid': u'361'}},
#     u'lastName': u'CUBAN CIGARS TRADE',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'593'},
#    {u'addressList': {u'address': {u'address1': u'Baja California 255, Edificio B. Oficina 103, Condesa',
#       u'city': u'Mexico, D.F.',
#       u'country': u'Mexico',
#       u'postalCode': u'06500',
#       u'uid': u'362'}},
#     u'lastName': u'CUBANATUR',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'621'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'363'}},
#     u'lastName': u'CUBATABACO',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'622'},
#    {u'addressList': {u'address': {u'address1': u'1649 Adolfo Prieto, Colonia del Valle',
#       u'city': u'Mexico City',
#       u'country': u'Mexico',
#       u'uid': u'365'}},
#     u'lastName': u'CUMEXINT, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'636'},
#    {u'addressList': {u'address': {u'address1': u'Case Postale 236, 10 Bis Rue Du Vieux College 12-11',
#       u'city': u'Geneva',
#       u'country': u'Switzerland',
#       u'uid': u'376'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'DELVEST HOLDING COMPANY',
#       u'type': u'a.k.a.',
#       u'uid': u'556'}},
#     u'lastName': u'DELVEST HOLDING, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'651'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'408'}},
#     u'lastName': u'EDICIONES CUBANAS',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'701'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'409'}},
#     u'lastName': u'EDYJU, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'702'},
#    {u'addressList': {u'address': [{u'address1': u'32 Main Street',
#        u'city': u'Georgetown',
#        u'country': u'Guyana',
#        u'uid': u'438'},
#       {u'address1': u'24 Rue Du Quatre Septembre',
#        u'city': u'Paris',
#        u'country': u'France',
#        u'uid': u'439'},
#       {u'address1': u'Belas Airport',
#        u'city': u'Luanda',
#        u'country': u'Angola',
#        u'uid': u'440'},
#       {u'address1': u'Dobrininskaya No. 7, Sec 5',
#        u'city': u'Moscow',
#        u'country': u'Russia',
#        u'uid': u'441'},
#       {u'address1': u'Corrientes 545 Primer Piso',
#        u'city': u'Buenos Aires',
#        u'country': u'Argentina',
#        u'uid': u'442'},
#       {u'address1': u'Frankfurter TOR 8-A',
#        u'city': u'Berlin',
#        u'country': u'Germany',
#        u'uid': u'443'},
#       {u'address1': u'1 Place Ville Marie, Suite 3431',
#        u'city': u'Montreal',
#        u'country': u'Canada',
#        u'uid': u'444'},
#       {u'address1': u'Parizska 17',
#        u'city': u'Prague',
#        u'country': u'Czech Republic',
#        u'uid': u'445'},
#       {u'address1': u'Paseo de la Republica 126',
#        u'city': u'Lima',
#        u'country': u'Peru',
#        u'uid': u'446'},
#       {u'address1': u'Piarco Airport',
#        u'city': u'Port au Prince',
#        u'country': u'Haiti',
#        u'uid': u'447'},
#       {u'address1': u'c/o Anglo-Caribbean Shipping Co. Ltd.',
#        u'address2': u'Ibex House, The Minories',
#        u'city': u'London',
#        u'country': u'United Kingdom',
#        u'postalCode': u'EC3N 1DY',
#        u'uid': u'448'},
#       {u'address1': u'Norman Manley International Airport',
#        u'city': u'Kingston',
#        u'country': u'Jamaica',
#        u'uid': u'449'},
#       {u'address1': u'Melchor Ocampo 469, 5DF',
#        u'city': u'Mexico City',
#        u'country': u'Mexico',
#        u'uid': u'450'},
#       {u'address1': u'Calle 29 y Avda Justo Arosemena',
#        u'city': u'Panama City',
#        u'country': u'Panama',
#        u'uid': u'451'},
#       {u'address1': u'Grantley Adams Airport, Christ Church',
#        u'country': u'Barbados',
#        u'uid': u'452'},
#       {u'city': u'Madrid', u'country': u'Spain', u'uid': u'453'}]},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'CUBANA AIRLINES',
#       u'type': u'a.k.a.',
#       u'uid': u'583'}},
#     u'lastName': u'EMPRESA CUBANA DE AVIACION',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'735'},
#    {u'addressList': {u'address': [{u'city': u'Paris',
#        u'country': u'France',
#        u'uid': u'454'},
#       {u'city': u'Milan', u'country': u'Italy', u'uid': u'455'},
#       {u'city': u'Moscow', u'country': u'Russia', u'uid': u'456'},
#       {u'city': u'Madrid', u'country': u'Spain', u'uid': u'457'},
#       {u'city': u'Cologne', u'country': u'Germany', u'uid': u'458'},
#       {u'address1': u'Downsview',
#        u'city': u'Ontario',
#        u'country': u'Canada',
#        u'uid': u'459'},
#       {u'city': u'Tokyo', u'country': u'Japan', u'uid': u'460'}]},
#     u'akaList': {u'aka': [{u'category': u'strong',
#        u'lastName': u'CARIBEX',
#        u'type': u'a.k.a.',
#        u'uid': u'599'},
#       {u'category': u'strong',
#        u'lastName': u'CARIBBEAN EXPORT ENTERPRISE',
#        u'type': u'a.k.a.',
#        u'uid': u'600'}]},
#     u'lastName': u'EMPRESA CUBANA DE PESCADOS Y MARISCOS',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'751'},
#    {u'addressList': {u'address': {u'city': u'Buenos Aires',
#       u'country': u'Argentina',
#       u'uid': u'461'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'CUBATUR',
#       u'type': u'a.k.a.',
#       u'uid': u'613'}},
#     u'lastName': u'EMPRESA DE TURISMO NACIONAL Y INTERNACIONAL',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'758'},
#    {u'addressList': {u'address': {u'address1': u'Devonshire House, 1 Devonshire Street',
#       u'city': u'London',
#       u'country': u'United Kingdom',
#       u'uid': u'465'}},
#     u'lastName': u'ETCO INTERNATIONAL COMMODITIES LTD.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'767'},
#    {u'addressList': {u'address': {u'address1': u'Kawabe Building, 1-5 Kanda Nishiki-Cho, Chiyoda-Ku',
#       u'city': u'Tokyo',
#       u'country': u'Japan',
#       u'uid': u'466'}},
#     u'lastName': u'ETCO INTERNATIONAL COMPANY, LIMITED',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'768'},
#    {u'addressList': {u'address': {u'address1': u'5250 Ferrier Street',
#       u'city': u'Montreal',
#       u'country': u'Canada',
#       u'stateOrProvince': u'Quebec',
#       u'uid': u'500'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'GALAX INC.',
#       u'type': u'a.k.a.',
#       u'uid': u'641'}},
#     u'lastName': u'GALAX TRADING CO., LTD.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'815'},
#    {u'addressList': {u'address': {u'address1': u'Vinales Tours, Oaxaca 80, Roma',
#       u'city': u'Mexico, D.F.',
#       u'country': u'Mexico',
#       u'uid': u'566'}},
#     u'firstName': u'Jose',
#     u'lastName': u'GUTIERREZ REYES',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Individual',
#     u'uid': u'899'},
#    {u'addressList': {u'address': {u'address1': u'20 Ironmonger Lane',
#       u'city': u'London',
#       u'country': u'United Kingdom',
#       u'postalCode': u'EC2V 8EY',
#       u'uid': u'571'}},
#     u'lastName': u'HAVANA INTERNATIONAL BANK, LTD.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'906'},
#    {u'addressList': {u'address': {u'address1': u'54 Rue Richelieu',
#       u'city': u'Paris',
#       u'country': u'France',
#       u'uid': u'572'}},
#     u'lastName': u'HAVANATUR',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'907'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'660'}},
#     u'lastName': u'INSTITUTO NACIONAL DE TURISMO DE CUBA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1042'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'661'}},
#     u'lastName': u'INTERCONSULT',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1043'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'793'}},
#     u'lastName': u'KAVE, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1241'},
#    {u'addressList': {u'address': [{u'city': u'Pyongyang',
#        u'country': u'Korea, North',
#        u'uid': u'825'},
#       {u'city': u'Moscow', u'country': u'Russia', u'uid': u'826'},
#       {u'city': u'Barcelona', u'country': u'Spain', u'uid': u'827'},
#       {u'city': u'Rostock', u'country': u'Germany', u'uid': u'828'},
#       {u'city': u'Genoa', u'country': u'Italy', u'uid': u'829'},
#       {u'city': u'Syczecin', u'country': u'Poland', u'uid': u'830'},
#       {u'city': u'Rotterdam', u'country': u'Netherlands', u'uid': u'831'},
#       {u'country': u'Mexico', u'uid': u'832'},
#       {u'city': u'Buenos Aires', u'country': u'Argentina', u'uid': u'833'},
#       {u'city': u'Montreal', u'country': u'Canada', u'uid': u'834'},
#       {u'city': u'Varna', u'country': u'Bulgaria', u'uid': u'835'}]},
#     u'akaList': {u'aka': [{u'category': u'strong',
#        u'lastName': u'CUFLET',
#        u'type': u'a.k.a.',
#        u'uid': u'888'},
#       {u'category': u'strong',
#        u'lastName': u'CUBAN FREIGHT ENTERPRISE',
#        u'type': u'a.k.a.',
#        u'uid': u'889'}]},
#     u'lastName': u'LA EMPRESA CUBANA DE FLETES',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1287'},
#    {u'addressList': {u'address': {u'address1': u'San Martin 323, Piso 14',
#       u'city': u'Buenos Aires',
#       u'country': u'Argentina',
#       u'uid': u'848'}},
#     u'lastName': u'LEVERAGE, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1316'},
#    {u'addressList': {u'address': {u'address1': u'Paseo de Pereda 36, Apartado 141',
#       u'city': u'Santander',
#       u'country': u'Spain',
#       u'postalCode': u'39004',
#       u'uid': u'990'}},
#     u'lastName': u'NAVIERA MARITIMA DE AROSA, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1544'},
#    {u'addressList': {u'address': {u'address1': u'Boezembolcht 23',
#       u'city': u'Rotterdam',
#       u'country': u'Netherlands',
#       u'uid': u'997'}},
#     u'lastName': u'NIREF',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1555'},
#    {u'addressList': {u'address': {u'country': u'Liechtenstein',
#       u'uid': u'1006'}},
#     u'lastName': u'NORDSTRAND LTD.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1570'},
#    {u'addressList': {u'address': {u'address1': u'33 Akti Maouli',
#       u'city': u'Pireas (Piraeus)',
#       u'country': u'Greece',
#       u'postalCode': u'185-35',
#       u'uid': u'1007'}},
#     u'lastName': u'NORDSTRAND MARITIME AND TRADING COMPANY',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1571'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'1008'}},
#     u'firstName': u'Manuel Antonio',
#     u'lastName': u'NORIEGA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Individual',
#     u'uid': u'1572'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'1052'}},
#     u'lastName': u'PANAMERICAN IMPORT AND EXPORT COMMERCIAL CORPORATION',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1641'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'1069'}},
#     u'lastName': u'PESCABRAVA, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1660'},
#    {u'addressList': {u'address': {u'country': u'Mexico', u'uid': u'1100'}},
#     u'lastName': u'PRELASA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1700'},
#    {u'addressList': {u'address': {u'address1': u'1010 O Rue Ste. Catherine',
#       u'city': u'Montreal',
#       u'country': u'Canada',
#       u'postalCode': u'PQ H303 IGI',
#       u'uid': u'1101'}},
#     u'lastName': u'PRENSA LATINA CANADA LTD.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1701'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'1102'}},
#     u'lastName': u'PRENSA LATINA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1702'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'1237'}},
#     u'lastName': u'SERVINAVES, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'1888'},
#    {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'1256'}},
#     u'firstName': u'Felicidad',
#     u'lastName': u'SIEIRO DE NORIEGA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Individual',
#     u'uid': u'1910'},
#    {u'addressList': {u'address': {u'address1': u'Edificio Saldivar',
#       u'city': u'Panama City',
#       u'country': u'Panama',
#       u'uid': u'1394'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'TROVER, S.A.',
#       u'type': u'a.k.a.',
#       u'uid': u'1409'}},
#     u'lastName': u'TROBER, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'2109'},
#    {u'addressList': {u'address': {u'address1': u'Lietzenburger Strasse 51',
#       u'city': u'Berlin',
#       u'country': u'Germany',
#       u'uid': u'1395'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'TROPICANA TOURS GMBH',
#       u'type': u'a.k.a.',
#       u'uid': u'1410'}},
#     u'lastName': u'TROPIC TOURS GMBH',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'2110'},
#    {u'addressList': {u'address': {u'country': u'Spain', u'uid': u'1430'}},
#     u'lastName': u'VIAJES GUAMA, S.A.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'2184'},
#    {u'addressList': {u'address': [{u'city': u'Cancun',
#        u'country': u'Mexico',
#        u'uid': u'1431'},
#       {u'city': u'Guadalajara', u'country': u'Mexico', u'uid': u'1432'},
#       {u'city': u'Mexico City', u'country': u'Mexico', u'uid': u'1433'},
#       {u'city': u'Monterey', u'country': u'Mexico', u'uid': u'1434'},
#       {u'city': u'Roma', u'country': u'Mexico', u'uid': u'1435'}]},
#     u'lastName': u'VINALES TOURS',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'2186'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Muhammad',
#       u'lastName': u'ZAYDAN',
#       u'type': u'a.k.a.',
#       u'uid': u'1795'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'10 Dec 1948',
#       u'mainEntry': u'true',
#       u'uid': u'1000'}},
#     u'firstName': u'Abu',
#     u'lastName': u'ABBAS',
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Director of PALESTINE LIBERATION FRONT - ABU ABBAS FACTION',
#     u'uid': u'2674'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'03 May 1938',
#       u'mainEntry': u'true',
#       u'uid': u'1001'}},
#     u'firstName': u'Shaykh Umar Abd',
#     u'lastName': u'AL RAHMAN',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Egypt',
#       u'uid': u'1002'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u"Chief Ideological Figure of ISLAMIC GAMA'AT",
#     u'uid': u'2675'},
#    {u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Ayman',
#        u'lastName': u'AL-ZAWAHIRI',
#        u'type': u'a.k.a.',
#        u'uid': u'4760'},
#       {u'category': u'strong',
#        u'firstName': u'Ahmad Fuad',
#        u'lastName': u'SALIM',
#        u'type': u'a.k.a.',
#        u'uid': u'4761'},
#       {u'category': u'strong',
#        u'firstName': u'Aiman Muhammad Rabi',
#        u'lastName': u'AL-ZAWAHIRI',
#        u'type': u'a.k.a.',
#        u'uid': u'4787'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'19 Jun 1951',
#       u'mainEntry': u'true',
#       u'uid': u'1003'}},
#     u'firstName': u'Dr. Ayman',
#     u'idList': {u'id': [{u'idNumber': u'19820215',
#        u'idType': u'Passport',
#        u'uid': u'1001'},
#       {u'idCountry': u'Egypt',
#        u'idNumber': u'1084010',
#        u'idType': u'Passport',
#        u'uid': u'1000'}]},
#     u'lastName': u'AL ZAWAHIRI',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Giza, Egypt',
#       u'uid': u'1004'}},
#     u'programList': {u'program': [u'SDT', u'SDGT']},
#     u'sdnType': u'Individual',
#     u'title': u'Operational and Military Leader of JIHAD GROUP',
#     u'uid': u'2676'},
#    {u'addressList': {u'address': {u'country': u'Egypt', u'uid': u'1835'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Colonel Abbud',
#       u'lastName': u'ZUMAR',
#       u'type': u'a.k.a.',
#       u'uid': u'1796'}},
#     u'firstName': u'Abbud',
#     u'lastName': u'AL-ZUMAR',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Egypt',
#       u'uid': u'1005'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Factional Leader of JIHAD GROUP',
#     u'uid': u'2677'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1946',
#       u'mainEntry': u'true',
#       u'uid': u'1006'}},
#     u'firstName': u'Abd Al Aziz',
#     u'lastName': u'AWDA',
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Chief Ideological Figure of PALESTINIAN ISLAMIC JIHAD - SHIQAQI',
#     u'uid': u'2678'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'1938',
#        u'mainEntry': u'true',
#        u'uid': u'1007'},
#       {u'dateOfBirth': u'1936', u'mainEntry': u'false', u'uid': u'3929'}]},
#     u'firstName': u'Shaykh Muhammad Husayn',
#     u'idList': {u'id': {u'idNumber': u'Subject to Secondary Sanctions Pursuant to the Hizballah Financial Sanctions Regulations',
#       u'idType': u'Additional Sanctions Information -',
#       u'uid': u'120229'}},
#     u'lastName': u'FADLALLAH',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Najf Al Ashraf (Najaf), Iraq',
#       u'uid': u'1008'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Leading Ideological Figure of HIZBALLAH',
#     u'uid': u'2679'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'George',
#       u'lastName': u'HABASH',
#       u'type': u'a.k.a.',
#       u'uid': u'1797'}},
#     u'firstName': u'George',
#     u'lastName': u'HABBASH',
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Secretary General of POPULAR FRONT FOR THE LIBERATION OF PALESTINE',
#     u'uid': u'2680'},
#    {u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Nayif',
#        u'lastName': u'HAWATMEH',
#        u'type': u'a.k.a.',
#        u'uid': u'1798'},
#       {u'category': u'strong',
#        u'firstName': u'Nayif',
#        u'lastName': u'HAWATMAH',
#        u'type': u'a.k.a.',
#        u'uid': u'1799'},
#       {u'category': u'strong',
#        u'firstName': u'Abu',
#        u'lastName': u'KHALID',
#        u'type': u'a.k.a.',
#        u'uid': u'1800'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1933',
#       u'mainEntry': u'true',
#       u'uid': u'1009'}},
#     u'firstName': u'Nayif',
#     u'lastName': u'HAWATMA',
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Secretary General of DEMOCRATIC FRONT FOR THE LIBERATION OF PALESTINE - HAWATMEH FACTION',
#     u'uid': u'2681'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'15 Jan 1955',
#       u'mainEntry': u'true',
#       u'uid': u'1010'}},
#     u'firstName': u'Mohammad Shawqi',
#     u'idList': {u'id': {u'idCountry': u'Egypt',
#       u'idNumber': u'304555',
#       u'idType': u'Passport',
#       u'uid': u'1002'}},
#     u'lastName': u'ISLAMBOULI',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Egypt',
#       u'uid': u'1011'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u"Military Leader of ISLAMIC GAMA'AT",
#     u'uid': u'2682'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Ahmad',
#       u'lastName': u'JIBRIL',
#       u'type': u'a.k.a.',
#       u'uid': u'1823'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1938',
#       u'mainEntry': u'true',
#       u'uid': u'1012'}},
#     u'firstName': u'Ahmad',
#     u'lastName': u'JABRIL',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Ramleh, Israel',
#       u'uid': u'1013'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Secretary General of POPULAR FRONT FOR THE LIBERATION OF PALESTINE - GENERAL COMMAND',
#     u'uid': u'2683'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1930',
#       u'mainEntry': u'true',
#       u'uid': u'1016'}},
#     u'firstName': u'Talal Muhammad Rashid',
#     u'lastName': u'NAJI',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Al Nasiria, Palestine',
#       u'uid': u'1017'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Principal Deputy of POPULAR FRONT FOR THE LIBERATION OF PALESTINE - GENERAL COMMAND',
#     u'uid': u'2685'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Hasan Abd-al-Karim',
#       u'lastName': u'NASRALLAH',
#       u'type': u'a.k.a.',
#       u'uid': u'22740'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'31 Aug 1960',
#        u'mainEntry': u'true',
#        u'uid': u'1018'},
#       {u'dateOfBirth': u'31 Aug 1953',
#        u'mainEntry': u'false',
#        u'uid': u'3930'},
#       {u'dateOfBirth': u'31 Aug 1955',
#        u'mainEntry': u'false',
#        u'uid': u'3931'},
#       {u'dateOfBirth': u'31 Aug 1958',
#        u'mainEntry': u'false',
#        u'uid': u'3932'}]},
#     u'firstName': u'Hasan',
#     u'idList': {u'id': [{u'idCountry': u'Lebanon',
#        u'idNumber': u'042833',
#        u'idType': u'Passport',
#        u'uid': u'1004'},
#       {u'idNumber': u'Subject to Secondary Sanctions Pursuant to the Hizballah Financial Sanctions Regulations',
#        u'idType': u'Additional Sanctions Information -',
#        u'uid': u'120223'}]},
#     u'lastName': u'NASRALLAH',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Al Basuriyah, Lebanon',
#       u'uid': u'1019'}},
#     u'programList': {u'program': [u'SYRIA', u'SDT']},
#     u'sdnType': u'Individual',
#     u'title': u'Secretary General of HIZBALLAH',
#     u'uid': u'2686'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Sabri Khalil Abd Al Qadir',
#       u'lastName': u'AL BANNA',
#       u'type': u'a.k.a.',
#       u'uid': u'1801'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'May 1937',
#        u'mainEntry': u'true',
#        u'uid': u'1020'},
#       {u'dateOfBirth': u'May 1940', u'mainEntry': u'false', u'uid': u'3933'}]},
#     u'firstName': u'Abu',
#     u'lastName': u'NIDAL',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Jaffa, Israel',
#       u'uid': u'1021'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Founder and Secretary General of ABU NIDAL ORGANIZATION',
#     u'uid': u'2687'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'02 Jun 1957',
#        u'mainEntry': u'true',
#        u'uid': u'1022'},
#       {u'dateOfBirth': u'03 Jun 1957',
#        u'mainEntry': u'false',
#        u'uid': u'3934'}]},
#     u'firstName': u'Talat Fouad',
#     u'lastName': u'QASEM',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Al Mina, Egypt',
#       u'uid': u'1023'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u"Propaganda Leader of ISLAMIC GAMA'AT",
#     u'uid': u'2688'},
#    {u'firstName': u'Fathi',
#     u'lastName': u'SHAQAQI',
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Secretary General of PALESTINIAN ISLAMIC JIHAD-SHIQAQI',
#     u'uid': u'2689'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1947',
#       u'mainEntry': u'true',
#       u'uid': u'1024'}},
#     u'firstName': u'Subhi',
#     u'lastName': u'TUFAYLI',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Biqa Valley, Lebanon',
#       u'uid': u'1025'}},
#     u'programList': {u'program': u'SDT'},
#     u'sdnType': u'Individual',
#     u'title': u'Former Secretary General and Current Senior Figure of HIZBALLAH',
#     u'uid': u'2690'},
#    {u'addressList': {u'address': {u'city': u'Gaza Strip',
#       u'country': u'undetermined',
#       u'uid': u'1849'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1938',
#       u'mainEntry': u'true',
#       u'uid': u'1026'}},
#     u'firstName': u'Sheik Ahmed Ismail',
#     u'lastName': u'YASSIN',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'al-Jawrah, al-Majdal District, Gaza',
#       u'uid': u'1027'}},
#     u'programList': {u'program': [u'SDT', u'SDGT']},
#     u'sdnType': u'Individual',
#     u'uid': u'2691'},
#    {u'addressList': {u'address': [{u'address1': u'57 Rue du Rhone',
#        u'city': u'Geneva',
#        u'country': u'Switzerland',
#        u'postalCode': u'CH-1204',
#        u'uid': u'1965'},
#       {u'country': u'Panama', u'uid': u'7520'}]},
#     u'akaList': {u'aka': [{u'category': u'strong',
#        u'lastName': u'MIDCO FINANCIAL S.A.',
#        u'type': u'a.k.a.',
#        u'uid': u'1852'},
#       {u'category': u'strong',
#        u'lastName': u'MONTANA MANAGEMENT INC.',
#        u'type': u'a.k.a.',
#        u'uid': u'1853'}]},
#     u'idList': {u'id': {u'idCountry': u'United States',
#       u'idNumber': u'CH-660-0-469-982-0',
#       u'idType': u'US FEIN',
#       u'uid': u'1005'}},
#     u'lastName': u'MIDCO FINANCE S.A.',
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Switzerland',
#     u'sdnType': u'Entity',
#     u'uid': u'2831'},
#    {u'addressList': {u'address': {u'city': u'Saskatchewan',
#       u'country': u'Canada',
#       u'stateOrProvince': u'AB',
#       u'uid': u'1982'}},
#     u'lastName': u'COBALT REFINERY CO. INC.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'3748'},
#    {u'addressList': {u'address': {u'country': u'Cuba', u'uid': u'1983'}},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'GENERAL NICKEL SA',
#       u'type': u'a.k.a.',
#       u'uid': u'3331'}},
#     u'lastName': u'LA COMPANIA GENERAL DE NIQUEL',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'3749'},
#    {u'addressList': {u'address': {u'city': u'Saskatchewan',
#       u'country': u'Canada',
#       u'stateOrProvince': u'AB',
#       u'uid': u'1984'}},
#     u'lastName': u'INTERNATIONAL COBALT CO. INC.',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'3750'},
#    {u'addressList': {u'address': {u'country': u'Cuba', u'uid': u'1985'}},
#     u'lastName': u'MOA NICKEL SA',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Entity',
#     u'uid': u'3751'},
#    {u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Musa Abu',
#        u'lastName': u'MARZUK',
#        u'type': u'a.k.a.',
#        u'uid': u'3341'},
#       {u'category': u'strong',
#        u'firstName': u'Dr. Musa',
#        u'lastName': u'ABU-MARZUQ',
#        u'type': u'a.k.a.',
#        u'uid': u'3342'},
#       {u'category': u'strong',
#        u'firstName': u'Mousa Mohamed Abou',
#        u'lastName': u'MARZOOK',
#        u'type': u'a.k.a.',
#        u'uid': u'3343'},
#       {u'category': u'strong',
#        u'firstName': u"Sa'id",
#        u'lastName': u'ABU-MARZUQ',
#        u'type': u'a.k.a.',
#        u'uid': u'3344'},
#       {u'category': u'weak',
#        u'lastName': u"ABU-'UMAR",
#        u'type': u'a.k.a.',
#        u'uid': u'3345'},
#       {u'category': u'strong',
#        u'firstName': u'Musa Abu',
#        u'lastName': u'MARZOUK',
#        u'type': u'a.k.a.',
#        u'uid': u'5821'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'09 Feb 1951',
#       u'mainEntry': u'true',
#       u'uid': u'1029'}},
#     u'firstName': u'Mousa Mohammed',
#     u'idList': {u'id': [{u'idCountry': u'Egypt',
#        u'idNumber': u'92/664',
#        u'idType': u'Passport',
#        u'uid': u'1008'},
#       {u'idCountry': u'United States',
#        u'idNumber': u'523-33-8386',
#        u'idType': u'SSN',
#        u'uid': u'1009'}]},
#     u'lastName': u'ABU MARZOOK',
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Gaza, Egypt',
#       u'uid': u'1030'}},
#     u'programList': {u'program': [u'SDT', u'SDGT']},
#     u'sdnType': u'Individual',
#     u'title': u'Political Leader in Amman, Jordan and Damascus, Syria for HAMAS',
#     u'uid': u'3754'},
#    {u'addressList': {u'address': {u'city': u'Cali',
#       u'country': u'Colombia',
#       u'uid': u'2006'}},
#     u'akaList': {u'aka': [{u'category': u'weak',
#        u'lastName': u'PACHO',
#        u'type': u'a.k.a.',
#        u'uid': u'7776'},
#       {u'category': u'weak',
#        u'lastName': u'H7',
#        u'type': u'a.k.a.',
#        u'uid': u'7777'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'24 Aug 1951',
#        u'mainEntry': u'true',
#        u'uid': u'1031'},
#       {u'dateOfBirth': u'05 Jul 1951',
#        u'mainEntry': u'false',
#        u'uid': u'1032'}]},
#     u'firstName': u'Helmer',
#     u'idList': {u'id': [{u'idCountry': u'Colombia',
#        u'idNumber': u'16247821',
#        u'idType': u'Cedula No.',
#        u'uid': u'1010'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'J287011',
#        u'idType': u'Passport',
#        u'uid': u'1011'}]},
#     u'lastName': u'HERRERA BUITRAGO',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Individual',
#     u'uid': u'4106'},
#    {u'addressList': {u'address': {u'city': u'Cali',
#       u'country': u'Colombia',
#       u'uid': u'2007'}},
#     u'akaList': {u'aka': [{u'category': u'weak',
#        u'lastName': u'THE CHESS PLAYER',
#        u'type': u'a.k.a.',
#        u'uid': u'7793'},
#       {u'category': u'weak',
#        u'lastName': u'LUCAS',
#        u'type': u'a.k.a.',
#        u'uid': u'7794'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'31 Jan 1939',
#       u'mainEntry': u'true',
#       u'uid': u'1033'}},
#     u'firstName': u'Gilberto Jose',
#     u'idList': {u'id': [{u'idCountry': u'Colombia',
#        u'idNumber': u'6067015',
#        u'idType': u'Cedula No.',
#        u'uid': u'3404'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'6068015',
#        u'idType': u'Cedula No.',
#        u'uid': u'1012'},
#       {u'idCountry': u'Venezuela',
#        u'idNumber': u'10545599',
#        u'idType': u'Passport',
#        u'uid': u'1016'},
#       {u'idCountry': u'Argentina',
#        u'idNumber': u'77588',
#        u'idType': u'Passport',
#        u'uid': u'1015'},
#       {u'idCountry': u'Comoros',
#        u'idNumber': u'6067015',
#        u'idType': u'Passport',
#        u'uid': u'1014'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'T321642',
#        u'idType': u'Passport',
#        u'uid': u'1013'}]},
#     u'lastName': u'RODRIGUEZ OREJUELA',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Individual',
#     u'uid': u'4107'},
#    {u'addressList': {u'address': {u'address1': u'Casa No. 19, Avenida Lago, Ciudad Jardin',
#       u'city': u'Cali',
#       u'country': u'Colombia',
#       u'uid': u'2008'}},
#     u'akaList': {u'aka': [{u'category': u'weak',
#        u'lastName': u'EL SENOR',
#        u'type': u'a.k.a.',
#        u'uid': u'7783'},
#       {u'category': u'weak',
#        u'lastName': u'PATRICIA',
#        u'type': u'a.k.a.',
#        u'uid': u'7784'},
#       {u'category': u'weak',
#        u'lastName': u'PATRICIO',
#        u'type': u'a.k.a.',
#        u'uid': u'7785'},
#       {u'category': u'weak',
#        u'lastName': u'PATTY',
#        u'type': u'a.k.a.',
#        u'uid': u'7786'},
#       {u'category': u'weak',
#        u'lastName': u'PAT',
#        u'type': u'a.k.a.',
#        u'uid': u'7787'},
#       {u'category': u'weak',
#        u'lastName': u'MANUEL',
#        u'type': u'a.k.a.',
#        u'uid': u'7788'},
#       {u'category': u'weak',
#        u'lastName': u'MANOLO',
#        u'type': u'a.k.a.',
#        u'uid': u'7789'},
#       {u'category': u'weak',
#        u'lastName': u'MIKE',
#        u'type': u'a.k.a.',
#        u'uid': u'7790'},
#       {u'category': u'weak',
#        u'lastName': u'MAURO',
#        u'type': u'a.k.a.',
#        u'uid': u'7791'},
#       {u'category': u'weak',
#        u'lastName': u'DOCTOR M.R.O.',
#        u'type': u'a.k.a.',
#        u'uid': u'7792'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'23 Nov 1943',
#        u'mainEntry': u'true',
#        u'uid': u'1034'},
#       {u'dateOfBirth': u'15 Jul 1943',
#        u'mainEntry': u'false',
#        u'uid': u'1035'}]},
#     u'firstName': u'Miguel Angel',
#     u'idList': {u'id': {u'idCountry': u'Colombia',
#       u'idNumber': u'6095803',
#       u'idType': u'Cedula No.',
#       u'uid': u'1017'}},
#     u'lastName': u'RODRIGUEZ OREJUELA',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Individual',
#     u'uid': u'4108'},
#    {u'addressList': {u'address': {u'city': u'Cali',
#       u'country': u'Colombia',
#       u'uid': u'2009'}},
#     u'akaList': {u'aka': [{u'category': u'weak',
#        u'lastName': u'CHEPE',
#        u'type': u'a.k.a.',
#        u'uid': u'7778'},
#       {u'category': u'weak',
#        u'lastName': u'DON CHEPE',
#        u'type': u'a.k.a.',
#        u'uid': u'7779'},
#       {u'category': u'weak',
#        u'lastName': u'EL GORDO CHEPE',
#        u'type': u'a.k.a.',
#        u'uid': u'7780'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'01 Oct 1943',
#       u'mainEntry': u'true',
#       u'uid': u'1036'}},
#     u'firstName': u'Jose',
#     u'idList': {u'id': {u'idCountry': u'Colombia',
#       u'idNumber': u'AB149814',
#       u'idType': u'Passport',
#       u'uid': u'1019'}},
#     u'lastName': u'SANTACRUZ LONDONO',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Individual',
#     u'uid': u'4109'},
#    {u'addressList': {u'address': [{u'address1': u'Calle 13A 64-50 F102',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'2061'},
#       {u'address1': u'Carrera 4 12-41 of. 1501, Edificio Seguros Bolivar',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'2062'},
#       {u'address1': u'Calle 13 3-32 piso 13',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'2063'},
#       {u'address1': u'Calle 18, No. 106-96 of. 201/202',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'2064'}]},
#     u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'INMOBILIARIA SAMARIA LTDA.',
#       u'type': u'f.k.a.',
#       u'uid': u'3569'}},
#     u'idList': {u'id': {u'idCountry': u'Colombia',
#       u'idNumber': u'890937859-0',
#       u'idType': u'NIT #',
#       u'uid': u'1021'}},
#     u'lastName': u'NEGOCIOS LOS SAUCES LTDA. Y CIA. S.C.S.',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Entity',
#     u'uid': u'4126'},
#    {u'addressList': {u'address': [{u'address1': u'Carrera 4 No. 4-21 of. 1501, Edificio Seguros Bolivar',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'2095'},
#       {u'address1': u'Apartado Aereo 10077',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'2096'}]},
#     u'idList': {u'id': {u'idCountry': u'Colombia',
#       u'idNumber': u'890328835-1',
#       u'idType': u'NIT #',
#       u'uid': u'1023'}},
#     u'lastName': u'NEGOCIOS LOS SAUCES LTDA.',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Entity',
#     u'uid': u'4139'},
#    {u'addressList': {u'address': [{u'address1': u'Calle 21 Norte No. 3N-84',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'4736'},
#       {u'address1': u'c/o CAVIEDES DILEO Y CIA S.C.S.',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'4737'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'23 Nov 1952',
#       u'mainEntry': u'true',
#       u'uid': u'1039'}},
#     u'firstName': u'Leonardo',
#     u'idList': {u'id': [{u'idCountry': u'Colombia',
#        u'idNumber': u'16593470',
#        u'idType': u'Cedula No.',
#        u'uid': u'1030'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'OC444290',
#        u'idType': u'Passport',
#        u'uid': u'1033'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'AC444270',
#        u'idType': u'Passport',
#        u'uid': u'1032'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'AB151486',
#        u'idType': u'Passport',
#        u'uid': u'1031'}]},
#     u'lastName': u'CAVIEDES CRUZ',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Individual',
#     u'uid': u'4149'},
#    {u'addressList': {u'address': [{u'address1': u'c/o SOCIEDAD CONSTRUCTORA LA CASCADA S.A.',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'4372'},
#       {u'address1': u'c/o COMERCIALIZACION Y FINANCIACION DE AUTOMOTORES S.A.',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'4377'},
#       {u'address1': u'c/o INVERSIONES INTEGRAL LTDA.',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'4378'},
#       {u'address1': u'c/o MIRALUNA LTDA.',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'4379'},
#       {u'address1': u'c/o URBANIZACIONES Y CONSTRUCCIONES LTDA.',
#        u'address2': u'DE CALI',
#        u'city': u'Cali',
#        u'country': u'Colombia',
#        u'uid': u'4380'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'31 Mar 1965',
#       u'mainEntry': u'true',
#       u'uid': u'1060'}},
#     u'firstName': u'Ana Milena',
#     u'idList': {u'id': [{u'idCountry': u'Colombia',
#        u'idNumber': u'31929808',
#        u'idType': u'Cedula No.',
#        u'uid': u'1073'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'AB151189',
#        u'idType': u'Passport',
#        u'uid': u'1075'},
#       {u'idCountry': u'Colombia',
#        u'idNumber': u'31929808',
#        u'idType': u'Passport',
#        u'uid': u'1074'}]},
#     u'lastName': u'SANTACRUZ CASTRO',
#     u'programList': {u'program': u'SDNT'},
#     u'sdnType': u'Individual',
#     u'uid': u'4181'},
#    {u'lastName': u'HERMANN',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Vessel',
#     u'uid': u'4234',
#     u'vesselInfo': {u'callSign': u'CL2685',
#      u'grossRegisteredTonnage': u'1098',
#      u'tonnage': u'2597',
#      u'vesselFlag': u'Cuba',
#      u'vesselOwner': u'Compania Navegacion Golfo S.A.',
#      u'vesselType': u'General Cargo'}},
#    {u'lastName': u'MAR AZUL',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Vessel',
#     u'uid': u'4238',
#     u'vesselInfo': {u'callSign': u'CL2192',
#      u'grossRegisteredTonnage': u'212',
#      u'vesselFlag': u'Cuba',
#      u'vesselOwner': u'Samir de Navegacion S.A.',
#      u'vesselType': u'Tug'}},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'lastName': u'ANA I',
#       u'type': u'f.k.a.',
#       u'uid': u'3408'}},
#     u'lastName': u'SAND SWAN',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Vessel',
#     u'uid': u'4243',
#     u'vesselInfo': {u'callSign': u'P3QG3',
#      u'grossRegisteredTonnage': u'1116',
#      u'tonnage': u'2595',
#      u'vesselFlag': u'Cyprus',
#      u'vesselOwner': u'Sand & Swan Navigation Co. Ltd.',
#      u'vesselType': u'General Cargo'}},
#    {u'lastName': u'TIFON',
#     u'programList': {u'program': u'CUBA'},
#     u'sdnType': u'Vessel',
#     u'uid': u'4249',
#     u'vesselInfo': {u'callSign': u'CL2059',
#      u'grossRegisteredTonnage': u'164',
#      u'vesselFlag': u'Cuba',
#      u'vesselOwner': u'Samir de Navegacion S.A.',
#      u'vesselType': u'Tug'}},
#    {u'addressList': {u'address': {u'city': u'Damascus',
#       u'country': u'Syria',
#       u'uid': u'2256'}},
#     u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Dr. Ramadan',
#        u'lastName': u'ABDULLAH',
#        u'type': u'a.k.a.',
#        u'uid': u'3414'},
#       {u'category': u'strong',
#        u'firstName': u'Dr. Ramadan Abdullah',
#        u'lastName': u'SHALLAH',
#        u'type': u'a.k.a.',
#        u'uid': u'3415'},
#       {u'category': u'strong',
#        u'firstName': u'Ramadan Abdalla Mohamed',
#        u'lastName': u'SHALLAH',
#        u'type': u'a.k.a.',
#        u'uid': u'3416'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'01 Jan 1958',
#       u'mainEntry': u'true',
# ...
#     u'sdnType': u'Individual',
#     u'uid': u'7861'},
#    {u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Taha Yassin',
#        u'lastName': u'RAMADAN',
#        u'type': u'a.k.a.',
#        u'uid': u'5662'},
#       {u'category': u'strong',
#        u'firstName': u'Taha Yasin',
#        u'lastName': u'RAMADAN',
#        u'type': u'a.k.a.',
#        u'uid': u'5663'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'circa 1938',
#       u'mainEntry': u'true',
#       u'uid': u'2133'}},
#     u'firstName': u'Taha Yassin Ramadan',
#     u'lastName': u'AL-JIZRAWI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2134'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Former Vice President',
#     u'sdnType': u'Individual',
#     u'uid': u'7862'},
#    {u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Rukan abdal-Ghaffur Sulayman',
#        u'lastName': u'AL-MAJID',
#        u'type': u'a.k.a.',
#        u'uid': u'5664'},
#       {u'category': u'strong',
#        u'firstName': u'Rukan abd al-Gafur',
#        u'lastName': u'AL-MAJID',
#        u'type': u'a.k.a.',
#        u'uid': u'5665'},
#       {u'category': u'strong',
#        u'firstName': u'Rukan abd al-Ghaffur al-Majid',
#        u'lastName': u'AL-TIKRITI',
#        u'type': u'a.k.a.',
#        u'uid': u'5666'},
#       {u'category': u'strong',
#        u'firstName': u'Rukan Razuqi abd al-Gahfur',
#        u'lastName': u'AL-MAJID',
#        u'type': u'a.k.a.',
#        u'uid': u'5667'},
#       {u'category': u'strong',
#        u'firstName': u"Rukan 'abd al-Ghaffur al-Majid",
#        u'lastName': u'AL-TIKRITI',
#        u'type': u'a.k.a.',
#        u'uid': u'5668'},
#       {u'category': u'weak',
#        u'lastName': u'ABU WALID',
#        u'type': u'a.k.a.',
#        u'uid': u'5669'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1956',
#       u'mainEntry': u'true',
#       u'uid': u'2135'}},
#     u'firstName': u'Rukan Razuki abd-al-Ghafur Sulaiman',
#     u'lastName': u'AL-TIKRITI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2137'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Tikrit, Iraq',
#       u'uid': u'2136'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'head of Tribal Affairs Office in presidential office',
#     u'sdnType': u'Individual',
#     u'uid': u'7863'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'04 May 1955',
#       u'mainEntry': u'true',
#       u'uid': u'2138'}},
#     u'firstName': u'Jamal Mustafa Abdallah Sultan',
#     u'lastName': u'AL-TIKRITI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2140'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'al-Samnah, near Tikrit, Iraq',
#       u'uid': u'2139'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'deputy head of tribal affairs in presidential office',
#     u'sdnType': u'Individual',
#     u'uid': u'7864'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1938',
#       u'mainEntry': u'true',
#       u'uid': u'2141'}},
#     u'firstName': u'Mizban Khadr',
#     u'lastName': u'HADI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2143'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Mandali District, Diyala, Iraq',
#       u'uid': u'2142'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u"member, Ba'th party regional command and Revolutionary Command Council since 1991",
#     u'sdnType': u'Individual',
#     u'uid': u'7865'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Taha, Muhyi al-Din',
#       u'lastName': u'MARUF',
#       u'type': u'a.k.a.',
#       u'uid': u'5670'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1924',
#       u'mainEntry': u'true',
#       u'uid': u'2144'}},
#     u'firstName': u'Taha Muhyi-al-Din',
#     u'lastName': u"MA'RUF",
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2146'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Sulaymaniyah, Iraq',
#       u'uid': u'2145'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Vice President; member of Revolutionary Command Council',
#     u'sdnType': u'Individual',
#     u'uid': u'7866'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Tariq Mikhail',
#       u'lastName': u'AZIZ',
#       u'type': u'a.k.a.',
#       u'uid': u'5671'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'01 Jul 1936',
#       u'mainEntry': u'true',
#       u'uid': u'2147'}},
#     u'firstName': u'Tariq',
#     u'idList': {u'id': {u'idNumber': u'NO34409/129',
#       u'idType': u'Passport',
#       u'issueDate': u'01 Jul 1997',
#       u'uid': u'1994'}},
#     u'lastName': u'AZIZ',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2149'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Mosul or Baghdad, Iraq',
#       u'uid': u'2148'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Deputy Prime Minister',
#     u'sdnType': u'Individual',
#     u'uid': u'7867'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Walid Hamid Tawfiq',
#       u'lastName': u'AL-NASIRI',
#       u'type': u'a.k.a.',
#       u'uid': u'5672'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'circa 1950',
#       u'mainEntry': u'true',
#       u'uid': u'2150'}},
#     u'firstName': u'Walid Hamid Tawfiq',
#     u'lastName': u'AL-TIKRITI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2152'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Tikrit, Iraq',
#       u'uid': u'2151'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Governor of Basrah',
#     u'sdnType': u'Individual',
#     u'uid': u'7868'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'circa 1944',
#       u'mainEntry': u'true',
#       u'uid': u'2153'}},
#     u'firstName': u'Sultan Hashim Ahmad',
#     u'lastName': u'AL-TAI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2155'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Mosul, Iraq',
#       u'uid': u'2154'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Minister of Defense',
#     u'sdnType': u'Individual',
#     u'uid': u'7869'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1934',
#       u'mainEntry': u'true',
#       u'uid': u'2156'}},
#     u'firstName': u'Hikmat Mizban Ibrahim',
#     u'lastName': u'AL-AZZAWI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2158'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Diyala, Iraq',
#       u'uid': u'2157'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Former Deputy Prime Minister and Finance Minister',
#     u'sdnType': u'Individual',
#     u'uid': u'7870'},
#    {u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Mahmoud Diab',
#        u'lastName': u'AL-AHMAD',
#        u'type': u'a.k.a.',
#        u'uid': u'5673'},
#       {u'category': u'strong',
#        u'firstName': u'Mahmoud Dhiyab',
#        u'lastName': u'AL-AHMAD',
#        u'type': u'a.k.a.',
#        u'uid': u'5674'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1953',
#       u'mainEntry': u'true',
#       u'uid': u'2159'}},
#     u'firstName': u'Mahmud Dhiyab',
#     u'lastName': u'AL-AHMAD',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2161'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Mosul or Baghdad, Iraq',
#       u'uid': u'2160'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Former Minister of Interior',
#     u'sdnType': u'Individual',
#     u'uid': u'7871'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1942',
#       u'mainEntry': u'true',
#       u'uid': u'2162'}},
#     u'firstName': u'Ayad Futayyih Khalifa',
#     u'lastName': u'AL-RAWI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2164'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Rawah, Iraq',
#       u'uid': u'2163'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Quds Force Chief of Staff',
#     u'sdnType': u'Individual',
#     u'uid': u'7872'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'circa 1948',
#       u'mainEntry': u'true',
#       u'uid': u'2165'}},
#     u'firstName': u'Zuhair Talib abd-al-Sattar',
#     u'lastName': u'AL-NAQIB',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2166'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Director, Military Intelligence',
#     u'sdnType': u'Individual',
#     u'uid': u'7873'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'05 Apr 1938',
#       u'mainEntry': u'true',
#       u'uid': u'2167'}},
#     u'firstName': u'Amir Hamudi Hassan',
#     u'idList': {u'id': [{u'idNumber': u'H0100009',
#        u'idType': u'Passport',
#        u'issueDate': u'01 May 2002',
#        u'uid': u'1997'},
#       {u'idNumber': u'M0003264580', u'idType': u'Passport', u'uid': u'1996'},
#       {u'expirationDate': u'01 Oct 2005',
#        u'idNumber': u'NO33301/862',
#        u'idType': u'Passport',
#        u'issueDate': u'17 Oct 1997',
#        u'uid': u'1995'}]},
#     u'lastName': u"AL-SA'DI",
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2169'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Baghdad, Iraq',
#       u'uid': u'2168'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'presidential scientific advisor',
#     u'sdnType': u'Individual',
#     u'uid': u'7874'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1939',
#       u'mainEntry': u'true',
#       u'uid': u'2170'}},
#     u'firstName': u'Amir Rashid Muhammad',
#     u'lastName': u'AL-UBAIDI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2172'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Baghdad, Iraq',
#       u'uid': u'2171'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Minister of Oil',
#     u'sdnType': u'Individual',
#     u'uid': u'7875'},
#    {u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'1953',
#        u'mainEntry': u'true',
#        u'uid': u'2173'},
#       {u'dateOfBirth': u'1958', u'mainEntry': u'false', u'uid': u'2176'}]},
#     u'firstName': u'Husam Muhammad Amin',
#     u'lastName': u'AL-YASSIN',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2175'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Tikrit, Iraq',
#       u'uid': u'2174'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'head, National Monitoring Directorate',
#     u'sdnType': u'Individual',
#     u'uid': u'7876'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Mohammed Mahdi',
#       u'lastName': u'SALEH',
#       u'type': u'a.k.a.',
#       u'uid': u'5676'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': [{u'dateOfBirth': u'1947',
#        u'mainEntry': u'true',
#        u'uid': u'2177'},
#       {u'dateOfBirth': u'1949', u'mainEntry': u'false', u'uid': u'2180'}]},
#     u'firstName': u'Muhammad Mahdi',
#     u'lastName': u'AL-SALIH',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2179'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'al-Anbar Governorate, Iraq',
#       u'uid': u'2178'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'Minister of Trade',
#     u'sdnType': u'Individual',
#     u'uid': u'7877'},
#    {u'akaList': {u'aka': {u'category': u'strong',
#       u'firstName': u'Sabawi Ibrahim Hassan',
#       u'lastName': u'AL-TAKRITI',
#       u'type': u'a.k.a.',
#       u'uid': u'5677'}},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1947',
#       u'mainEntry': u'true',
#       u'uid': u'2181'}},
#     u'firstName': u"Sab'awi Ibrahim Hassan",
#     u'lastName': u'AL-TIKRITI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2183'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Tikrit, Iraq',
#       u'uid': u'2182'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'presidential advisor; half-brother of Saddam Hussein al-Tikriti',
#     u'sdnType': u'Individual',
#     u'uid': u'7878'},
#    {u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Watab Ibrahim',
#        u'lastName': u'AL-HASSAN',
#        u'type': u'a.k.a.',
#        u'uid': u'5678'},
#       {u'category': u'strong',
#        u'firstName': u'Watban',
#        u'lastName': u'AL-TAKRITI',
#        u'type': u'a.k.a.',
#        u'uid': u'5679'},
#       {u'category': u'strong',
#        u'firstName': u'Watban Ibrahim al-Hasan',
#        u'lastName': u'AL-TIKRITI',
#        u'type': u'a.k.a.',
#        u'uid': u'5680'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'1952',
#       u'mainEntry': u'true',
#       u'uid': u'2184'}},
#     u'firstName': u'Watban Ibrahim Hassan',
#     u'lastName': u'AL-TIKRITI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2186'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Tikrit, Iraq',
#       u'uid': u'2185'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'presidential advisor; half-brother of Saddam Hussein al-Tikriti',
#     u'sdnType': u'Individual',
#     u'uid': u'7879'},
#    {u'addressList': {u'address': {u'city': u'Geneva',
#       u'country': u'Switzerland',
#       u'uid': u'6798'}},
#     u'akaList': {u'aka': [{u'category': u'strong',
#        u'firstName': u'Barzan Ibrahim Hassan',
#        u'lastName': u'AL-TAKRITI',
#        u'type': u'a.k.a.',
#        u'uid': u'5681'},
#       {u'category': u'strong',
#        u'firstName': u'Barzan Ibrahim Hasan',
#        u'lastName': u'AL-TIKRITI',
#        u'type': u'a.k.a.',
#        u'uid': u'5682'}]},
#     u'dateOfBirthList': {u'dateOfBirthItem': {u'dateOfBirth': u'17 Feb 1951',
#       u'mainEntry': u'true',
#       u'uid': u'2187'}},
#     u'firstName': u'Barzan Ibrahim Hassan',
#     u'idList': {u'id': [{u'idNumber': u'M0009851/1',
#        u'idType': u'Passport',
#        u'uid': u'2000'},
#       {u'idNumber': u'NM0000860/114', u'idType': u'Passport', u'uid': u'1999'},
#       {u'idNumber': u'M0001666/970',
#        u'idType': u'Passport',
#        u'uid': u'1998'}]},
#     u'lastName': u'AL-TIKRITI',
#     u'nationalityList': {u'nationality': {u'country': u'Iraq',
#       u'mainEntry': u'true',
#       u'uid': u'2189'}},
#     u'placeOfBirthList': {u'placeOfBirthItem': {u'mainEntry': u'true',
#       u'placeOfBirth': u'Tikrit, Iraq',
#       u'uid': u'2188'}},
#     u'programList': {u'program': u'IRAQ2'},
#     u'remarks': u'presidential advisor; half-brother of Saddam Hussein al-Tikriti',
#     u'sdnType': u'Individual',
#     u'uid': u'7880'},
#    ...]}}

# %%
# This is just exploring the json

print type(traffic)
print traffic.keys()
print traffic['sdnList'].keys()
print type(traffic['sdnList']['sdnEntry'])
print len(traffic['sdnList']['sdnEntry'])
print traffic['sdnList']['sdnEntry'][0].keys()
traffic['sdnList']['sdnEntry'][10]
# Out:
# <type 'dict'>
# [u'sdnList']
# [u'_xmlns:xsi', u'publshInformation', u'_xmlns', u'sdnEntry']
# <type 'list'>
# 5533
# [u'uid', u'akaList', u'lastName', u'addressList', u'sdnType', u'programList']
# {u'addressList': {u'address': {u'country': u'Panama', u'uid': u'328'}},
#  u'lastName': u'COMERCIAL CIMEX, S.A.',
#  u'programList': {u'program': u'CUBA'},
#  u'sdnType': u'Entity',
#  u'uid': u'551'}

# %%
# Problem: Looks like you guys have different keys for different observations - so data will 
#    probably have some NA values - which is fine

# Here are the keys for the first 10 values
data = traffic['sdnList']['sdnEntry'][0:10]
for i in data:
    print i.keys()
# Out:
# [u'uid', u'akaList', u'lastName', u'addressList', u'sdnType', u'programList']
# [u'uid', u'akaList', u'lastName', u'addressList', u'sdnType', u'programList']
# [u'uid', u'akaList', u'lastName', u'addressList', u'sdnType', u'programList']
# [u'lastName', u'addressList', u'uid', u'sdnType', u'programList']
# [u'lastName', u'addressList', u'uid', u'sdnType', u'programList']
# [u'lastName', u'addressList', u'uid', u'sdnType', u'programList']
# [u'lastName', u'addressList', u'uid', u'sdnType', u'programList']
# [u'lastName', u'addressList', u'uid', u'sdnType', u'programList']
# [u'lastName', u'addressList', u'uid', u'sdnType', u'programList']
# [u'uid', u'akaList', u'lastName', u'addressList', u'sdnType', u'programList']

# %%
# However, look at this value

traffic['sdnList']['sdnEntry'][2]['addressList']
# Out:
# {u'address': [{u'address1': u'Zweierstrasse 35',
#    u'city': u'Zurich',
#    u'country': u'Switzerland',
#    u'postalCode': u'CH-8022',
#    u'uid': u'199'},
#   {u'address1': u'Avenida de Concha Espina 8',
#    u'city': u'Madrid',
#    u'country': u'Spain',
#    u'postalCode': u'E-28036',
#    u'uid': u'200'},
#   {u'address1': u'Dai-Ichi Bldg. 6th Floor, 10-2 Nihombashi, 2-chome, Chuo-ku',
#    u'city': u'Tokyo',
#    u'country': u'Japan',
#    u'postalCode': u'103',
#    u'uid': u'201'},
#   {u'address1': u'Federico Boyd Avenue & 51 Street',
#    u'city': u'Panama City',
#    u'country': u'Panama',
#    u'uid': u'202'}]}

# %% [markdown]
# The address key has multiple entries, including one of which that's a list. Iterating through this will produce
#
# `TypeError: list indices must be integers, not str`
#
# So that's something you'll need to take into account - non-uniform values
#
#
# Once you sort through that stuff, you can just use the following code structure.
#
# Just add column names as you get them - e.g. if you want to add a column called `ofac`, do:
#
#    `try:`
#       `table.insert(dict(`
#       `     ofac = i['ofac']`
#       `     ))`

# %%
# stream through each element in the list
# for each element in list:
#    insert list's elements into db
table = db[TABLE_NAME]
data = traffic['sdnList']['sdnEntry'][0:7]

for i in data:
            
        try:
            table.insert(dict(
                uid      = i['uid'],
                lastname = i['lastName'],
                sdnType  = i['sdnType']
            ))
            
        except ProgrammingError as err:
            print(err)

# %%
# Verify that it worked
conn = sqlite3.connect("ofac.db")
query = "SELECT * FROM ofac"
conn.execute(query).fetchall()
# Out:
# [(1, None, u'306', u'Entity', u'BANCO NACIONAL DE CUBA'),
#  (2, None, u'475', u'Entity', u'CASA DE CUBA'),
#  (3, None, u'306', u'Entity', u'BANCO NACIONAL DE CUBA'),
#  (4, None, u'475', u'Entity', u'CASA DE CUBA'),
#  (5, None, u'36', u'Entity', u'AEROCARIBBEAN AIRLINES'),
#  (6, None, u'173', u'Entity', u'ANGLO-CARIBBEAN CO., LTD.'),
#  (7, None, u'306', u'Entity', u'BANCO NACIONAL DE CUBA'),
#  (8, None, u'424', u'Entity', u'BOUTIQUE LA MAISON'),
#  (9, None, u'475', u'Entity', u'CASA DE CUBA'),
#  (10, None, u'480', u'Entity', u'CECOEX, S.A.'),
#  (11, None, u'535', u'Entity', u'CIMEX')]

# %% [markdown]
# ### For readability or POC. - can read it into Python with pandas

# %%
import pandas as pd

# we'll read in directly from the query
data_in_pandas = pd.read_sql_query(query, conn)
data_in_pandas
# Out:
#     id  city  uid sdnType                   lastname
# 0    1  None  306  Entity     BANCO NACIONAL DE CUBA
# 1    2  None  475  Entity               CASA DE CUBA
# 2    3  None  306  Entity     BANCO NACIONAL DE CUBA
# 3    4  None  475  Entity               CASA DE CUBA
# 4    5  None   36  Entity     AEROCARIBBEAN AIRLINES
# 5    6  None  173  Entity  ANGLO-CARIBBEAN CO., LTD.
# 6    7  None  306  Entity     BANCO NACIONAL DE CUBA
# 7    8  None  424  Entity         BOUTIQUE LA MAISON
# 8    9  None  475  Entity               CASA DE CUBA
# 9   10  None  480  Entity               CECOEX, S.A.
# 10  11  None  535  Entity                      CIMEX

# %% [markdown]
# # tl;dr: The json is pretty messy but once you clean it up uploading it into sqlite should be easy
