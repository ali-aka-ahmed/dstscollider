# %% [markdown]
# # Using the GitHub API
#
# **Forewarning: using the github api is decidely not as cool as using the reddit api or the twitter api. Just saying...**
#
# If you're reading this, you're on github so I'm assuming you know what it is.
# Here's the [documentation](https://developer.github.com/v3/) for the github API.
#
#
# Using the GitHub API requiers **authentication**.
#
# A lot of APIs require authentication. This is usually for security reasons or rate limiting (so that the API server doesn't get too bogged down).
#
# What this means is that, to authenticate with the GitHub API, we'll need to use an ***access token***. An access token is a credential we can generate on github's website. The token is a string that the API can read and associate with your account. You can think of it as a password of sorts for your account to use the API.
#
# You can learn more about authentication for the github API here. [hey what's up I'm a link to authentication for github](https://developer.github.com/v3/#authentication)
#
# Go [here](https://github.com/settings/tokens) to set-up your own personal tokens.

# %%
## Navigate there and obtain your authenication credentials
mytoken = "4401b54eb2ebf5cc5f5cac101223a96a1ed7f337"

# %% [markdown]
# Cool, you have an access token. Now what?
#
# We'll use an ***authorization header*** to send the API server metadata about our request. We'll make a dictionary of headers (API parameters) and pass it into our request using the **requests** library in our favorite programming language (Python, of course).
#
# ### Create your header in the following format
# `{"Authorization": "token 4401b54eb2ebf5cc5f5cac101223a96a1ed7f337"}`

# %%
import requests
import json

# create auhtorization header
headers = {"Authorization": "token 4401b54eb2ebf5cc5f5cac101223a96a1ed7f337"}

# make request to API
req = requests.get("https://api.github.com/users/jwilber", headers=headers)

# View output
print req.json()
# Out:
# {u'disk_usage': 154576, u'private_gists': 0, u'public_repos': 22, u'site_admin': False, u'subscriptions_url': u'https://api.github.com/users/jwilber/subscriptions', u'gravatar_id': u'', u'hireable': None, u'id': 8595819, u'followers_url': u'https://api.github.com/users/jwilber/followers', u'following_url': u'https://api.github.com/users/jwilber/following{/other_user}', u'collaborators': 4, u'total_private_repos': 2, u'blog': None, u'followers': 2, u'location': u'Berkeley/San Diego', u'type': u'User', u'email': None, u'bio': u'I enjoy statistics, data science, machine learning, surfing, and fitness. I use R and Python.', u'gists_url': u'https://api.github.com/users/jwilber/gists{/gist_id}', u'owned_private_repos': 2, u'company': None, u'events_url': u'https://api.github.com/users/jwilber/events{/privacy}', u'html_url': u'https://github.com/jwilber', u'updated_at': u'2017-01-19T05:49:43Z', u'plan': {u'collaborators': 0, u'name': u'personal', u'private_repos': 9999, u'space': 976562499}, u'received_events_url': u'https://api.github.com/users/jwilber/received_events', u'starred_url': u'https://api.github.com/users/jwilber/starred{/owner}{/repo}', u'public_gists': 0, u'name': u'Jared Wilber', u'organizations_url': u'https://api.github.com/users/jwilber/orgs', u'url': u'https://api.github.com/users/jwilber', u'created_at': u'2014-08-30T01:52:33Z', u'avatar_url': u'https://avatars.githubusercontent.com/u/8595819?v=3', u'repos_url': u'https://api.github.com/users/jwilber/repos', u'following': 2, u'login': u'jwilber', u'two_factor_authentication': False}

# %% [markdown]
# Essentially, there are several different urls specific to the github api that you can pass into the first parameter or `requests.get()` that will request different things.
#
# Examples:
# - https://api.github.com/users/[user_name]: Gets information about user
# - https://api.github.com/orgs/[organization_name]: Gets information about organization
# - https://api.github.com/repos/[repo_owner]/[repo_name]: Gets information about a specific repository

# %% [markdown]
# ## Params
#
# We can also add parameters to our github api requests. For example, we can use pagination to limit the number of responses that we obtain from the api (e.g. if a user had one million repos, we wouldn't want all of them at once, right? [wrong][jk])
#
# [Pagination](https://developer.github.com/v3/#pagination) just means that the API provider will only return a certain number of records per page. You can specify the page number that you want to access. To access all of the pages, you'll need to write a loop.
#
# We'll use a `params` variable to include these parameters in our header.
#
# We'll use two parameters:
#
# - `page`: page we want to access
# - `per_page`: number of items we want to see per page

# %%
# You can access the API in 2 ways, by listing the parameters directly in the url or by creating a separate params argument

# params = {"per_page": 50, "page": 1}
# response = requests.get("https://api.github.com/users/VikParuchuri/starred", headers=headers, params=params)
# page1_repos = response.json()


resp = requests.get("https://api.github.com/users/VikParuchuri/starred?page=1&per_page=10", headers=headers)
page = resp.json()
print page
# Out:
# [{u'issues_url': u'https://api.github.com/repos/apache/zeppelin/issues{/number}', u'deployments_url': u'https://api.github.com/repos/apache/zeppelin/deployments', u'stargazers_count': 2541, u'forks_url': u'https://api.github.com/repos/apache/zeppelin/forks', u'mirror_url': u'git://git.apache.org/incubator-zeppelin.git', u'subscription_url': u'https://api.github.com/repos/apache/zeppelin/subscription', u'notifications_url': u'https://api.github.com/repos/apache/zeppelin/notifications{?since,all,participating}', u'collaborators_url': u'https://api.github.com/repos/apache/zeppelin/collaborators{/collaborator}', u'updated_at': u'2017-02-16T07:36:54Z', u'private': False, u'pulls_url': u'https://api.github.com/repos/apache/zeppelin/pulls{/number}', u'issue_comment_url': u'https://api.github.com/repos/apache/zeppelin/issues/comments{/number}', u'labels_url': u'https://api.github.com/repos/apache/zeppelin/labels{/name}', u'has_wiki': False, u'full_name': u'apache/zeppelin', u'owner': {u'following_url': u'https://api.github.com/users/apache/following{/other_user}', u'events_url': u'https://api.github.com/users/apache/events{/privacy}', u'organizations_url': u'https://api.github.com/users/apache/orgs', u'url': u'https://api.github.com/users/apache', u'gists_url': u'https://api.github.com/users/apache/gists{/gist_id}', u'html_url': u'https://github.com/apache', u'subscriptions_url': u'https://api.github.com/users/apache/subscriptions', u'avatar_url': u'https://avatars.githubusercontent.com/u/47359?v=3', u'repos_url': u'https://api.github.com/users/apache/repos', u'received_events_url': u'https://api.github.com/users/apache/received_events', u'gravatar_id': u'', u'starred_url': u'https://api.github.com/users/apache/starred{/owner}{/repo}', u'site_admin': False, u'login': u'apache', u'type': u'Organization', u'id': 47359, u'followers_url': u'https://api.github.com/users/apache/followers'}, u'statuses_url': u'https://api.github.com/repos/apache/zeppelin/statuses/{sha}', u'id': 32848140, u'keys_url': u'https://api.github.com/repos/apache/zeppelin/keys{/key_id}', u'description': u'Mirror of Apache Zeppelin', u'tags_url': u'https://api.github.com/repos/apache/zeppelin/tags', u'downloads_url': u'https://api.github.com/repos/apache/zeppelin/downloads', u'assignees_url': u'https://api.github.com/repos/apache/zeppelin/assignees{/user}', u'contents_url': u'https://api.github.com/repos/apache/zeppelin/contents/{+path}', u'has_pages': True, u'git_refs_url': u'https://api.github.com/repos/apache/zeppelin/git/refs{/sha}', u'open_issues_count': 132, u'clone_url': u'https://github.com/apache/zeppelin.git', u'watchers_count': 2541, u'git_tags_url': u'https://api.github.com/repos/apache/zeppelin/git/tags{/sha}', u'milestones_url': u'https://api.github.com/repos/apache/zeppelin/milestones{/number}', u'languages_url': u'https://api.github.com/repos/apache/zeppelin/languages', u'size': 54868, u'homepage': u'', u'fork': False, u'commits_url': u'https://api.github.com/repos/apache/zeppelin/commits{/sha}', u'releases_url': u'https://api.github.com/repos/apache/zeppelin/releases{/id}', u'issue_events_url': u'https://api.github.com/repos/apache/zeppelin/issues/events{/number}', u'archive_url': u'https://api.github.com/repos/apache/zeppelin/{archive_format}{/ref}', u'comments_url': u'https://api.github.com/repos/apache/zeppelin/comments{/number}', u'events_url': u'https://api.github.com/repos/apache/zeppelin/events', u'contributors_url': u'https://api.github.com/repos/apache/zeppelin/contributors', u'html_url': u'https://github.com/apache/zeppelin', u'forks': 1282, u'compare_url': u'https://api.github.com/repos/apache/zeppelin/compare/{base}...{head}', u'open_issues': 132, u'git_url': u'git://github.com/apache/zeppelin.git', u'svn_url': u'https://github.com/apache/zeppelin', u'merges_url': u'https://api.github.com/repos/apache/zeppelin/merges', u'has_issues': False, u'ssh_url': u'git@github.com:apache/zeppelin.git', u'blobs_url': u'https://api.github.com/repos/apac ...

# %%
page1_repos
# Out:
# [{u'archive_url': u'https://api.github.com/repos/apache/zeppelin/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/apache/zeppelin/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/apache/zeppelin/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/apache/zeppelin/branches{/branch}',
#   u'clone_url': u'https://github.com/apache/zeppelin.git',
#   u'collaborators_url': u'https://api.github.com/repos/apache/zeppelin/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/apache/zeppelin/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/apache/zeppelin/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/apache/zeppelin/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/apache/zeppelin/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/apache/zeppelin/contributors',
#   u'created_at': u'2015-03-25T07:00:06Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/apache/zeppelin/deployments',
#   u'description': u'Mirror of Apache Zeppelin',
#   u'downloads_url': u'https://api.github.com/repos/apache/zeppelin/downloads',
#   u'events_url': u'https://api.github.com/repos/apache/zeppelin/events',
#   u'fork': False,
#   u'forks': 1282,
#   u'forks_count': 1282,
#   u'forks_url': u'https://api.github.com/repos/apache/zeppelin/forks',
#   u'full_name': u'apache/zeppelin',
#   u'git_commits_url': u'https://api.github.com/repos/apache/zeppelin/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/apache/zeppelin/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/apache/zeppelin/git/tags{/sha}',
#   u'git_url': u'git://github.com/apache/zeppelin.git',
#   u'has_downloads': True,
#   u'has_issues': False,
#   u'has_pages': True,
#   u'has_wiki': False,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/apache/zeppelin/hooks',
#   u'html_url': u'https://github.com/apache/zeppelin',
#   u'id': 32848140,
#   u'issue_comment_url': u'https://api.github.com/repos/apache/zeppelin/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/apache/zeppelin/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/apache/zeppelin/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/apache/zeppelin/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/apache/zeppelin/labels{/name}',
#   u'language': u'Java',
#   u'languages_url': u'https://api.github.com/repos/apache/zeppelin/languages',
#   u'merges_url': u'https://api.github.com/repos/apache/zeppelin/merges',
#   u'milestones_url': u'https://api.github.com/repos/apache/zeppelin/milestones{/number}',
#   u'mirror_url': u'git://git.apache.org/incubator-zeppelin.git',
#   u'name': u'zeppelin',
#   u'notifications_url': u'https://api.github.com/repos/apache/zeppelin/notifications{?since,all,participating}',
#   u'open_issues': 132,
#   u'open_issues_count': 132,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/47359?v=3',
#    u'events_url': u'https://api.github.com/users/apache/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/apache/followers',
#    u'following_url': u'https://api.github.com/users/apache/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/apache/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/apache',
#    u'id': 47359,
#    u'login': u'apache',
#    u'organizations_url': u'https://api.github.com/users/apache/orgs',
#    u'received_events_url': u'https://api.github.com/users/apache/received_events',
#    u'repos_url': u'https://api.github.com/users/apache/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/apache/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/apache/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/apache'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/apache/zeppelin/pulls{/number}',
#   u'pushed_at': u'2017-02-16T04:53:25Z',
#   u'releases_url': u'https://api.github.com/repos/apache/zeppelin/releases{/id}',
#   u'size': 54868,
#   u'ssh_url': u'git@github.com:apache/zeppelin.git',
#   u'stargazers_count': 2541,
#   u'stargazers_url': u'https://api.github.com/repos/apache/zeppelin/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/apache/zeppelin/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/apache/zeppelin/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/apache/zeppelin/subscription',
#   u'svn_url': u'https://github.com/apache/zeppelin',
#   u'tags_url': u'https://api.github.com/repos/apache/zeppelin/tags',
#   u'teams_url': u'https://api.github.com/repos/apache/zeppelin/teams',
#   u'trees_url': u'https://api.github.com/repos/apache/zeppelin/git/trees{/sha}',
#   u'updated_at': u'2017-02-16T07:36:54Z',
#   u'url': u'https://api.github.com/repos/apache/zeppelin',
#   u'watchers': 2541,
#   u'watchers_count': 2541},
#  {u'archive_url': u'https://api.github.com/repos/asciimoo/wuzz/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/asciimoo/wuzz/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/asciimoo/wuzz/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/asciimoo/wuzz/branches{/branch}',
#   u'clone_url': u'https://github.com/asciimoo/wuzz.git',
#   u'collaborators_url': u'https://api.github.com/repos/asciimoo/wuzz/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/asciimoo/wuzz/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/asciimoo/wuzz/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/asciimoo/wuzz/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/asciimoo/wuzz/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/asciimoo/wuzz/contributors',
#   u'created_at': u'2017-01-30T21:22:00Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/asciimoo/wuzz/deployments',
#   u'description': u'Interactive cli tool for HTTP inspection',
#   u'downloads_url': u'https://api.github.com/repos/asciimoo/wuzz/downloads',
#   u'events_url': u'https://api.github.com/repos/asciimoo/wuzz/events',
#   u'fork': False,
#   u'forks': 150,
#   u'forks_count': 150,
#   u'forks_url': u'https://api.github.com/repos/asciimoo/wuzz/forks',
#   u'full_name': u'asciimoo/wuzz',
#   u'git_commits_url': u'https://api.github.com/repos/asciimoo/wuzz/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/asciimoo/wuzz/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/asciimoo/wuzz/git/tags{/sha}',
#   u'git_url': u'git://github.com/asciimoo/wuzz.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/asciimoo/wuzz/hooks',
#   u'html_url': u'https://github.com/asciimoo/wuzz',
#   u'id': 80465011,
#   u'issue_comment_url': u'https://api.github.com/repos/asciimoo/wuzz/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/asciimoo/wuzz/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/asciimoo/wuzz/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/asciimoo/wuzz/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/asciimoo/wuzz/labels{/name}',
#   u'language': u'Go',
#   u'languages_url': u'https://api.github.com/repos/asciimoo/wuzz/languages',
#   u'merges_url': u'https://api.github.com/repos/asciimoo/wuzz/merges',
#   u'milestones_url': u'https://api.github.com/repos/asciimoo/wuzz/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'wuzz',
#   u'notifications_url': u'https://api.github.com/repos/asciimoo/wuzz/notifications{?since,all,participating}',
#   u'open_issues': 16,
#   u'open_issues_count': 16,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/20240?v=3',
#    u'events_url': u'https://api.github.com/users/asciimoo/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/asciimoo/followers',
#    u'following_url': u'https://api.github.com/users/asciimoo/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/asciimoo/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/asciimoo',
#    u'id': 20240,
#    u'login': u'asciimoo',
#    u'organizations_url': u'https://api.github.com/users/asciimoo/orgs',
#    u'received_events_url': u'https://api.github.com/users/asciimoo/received_events',
#    u'repos_url': u'https://api.github.com/users/asciimoo/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/asciimoo/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/asciimoo/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/asciimoo'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/asciimoo/wuzz/pulls{/number}',
#   u'pushed_at': u'2017-02-16T05:15:13Z',
#   u'releases_url': u'https://api.github.com/repos/asciimoo/wuzz/releases{/id}',
#   u'size': 961,
#   u'ssh_url': u'git@github.com:asciimoo/wuzz.git',
#   u'stargazers_count': 4842,
#   u'stargazers_url': u'https://api.github.com/repos/asciimoo/wuzz/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/asciimoo/wuzz/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/asciimoo/wuzz/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/asciimoo/wuzz/subscription',
#   u'svn_url': u'https://github.com/asciimoo/wuzz',
#   u'tags_url': u'https://api.github.com/repos/asciimoo/wuzz/tags',
#   u'teams_url': u'https://api.github.com/repos/asciimoo/wuzz/teams',
#   u'trees_url': u'https://api.github.com/repos/asciimoo/wuzz/git/trees{/sha}',
#   u'updated_at': u'2017-02-16T07:22:17Z',
#   u'url': u'https://api.github.com/repos/asciimoo/wuzz',
#   u'watchers': 4842,
#   u'watchers_count': 4842},
#  {u'archive_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/branches{/branch}',
#   u'clone_url': u'https://github.com/jakevdp/PythonDataScienceHandbook.git',
#   u'collaborators_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/contributors',
#   u'created_at': u'2016-08-10T14:24:36Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/deployments',
#   u'description': u'Jupyter Notebooks for the Python Data Science Handbook',
#   u'downloads_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/downloads',
#   u'events_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/events',
#   u'fork': False,
#   u'forks': 750,
#   u'forks_count': 750,
#   u'forks_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/forks',
#   u'full_name': u'jakevdp/PythonDataScienceHandbook',
#   u'git_commits_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/git/tags{/sha}',
#   u'git_url': u'git://github.com/jakevdp/PythonDataScienceHandbook.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/hooks',
#   u'html_url': u'https://github.com/jakevdp/PythonDataScienceHandbook',
#   u'id': 65388917,
#   u'issue_comment_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/labels{/name}',
#   u'language': u'Jupyter Notebook',
#   u'languages_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/languages',
#   u'merges_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/merges',
#   u'milestones_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'PythonDataScienceHandbook',
#   u'notifications_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/notifications{?since,all,participating}',
#   u'open_issues': 12,
#   u'open_issues_count': 12,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/781659?v=3',
#    u'events_url': u'https://api.github.com/users/jakevdp/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/jakevdp/followers',
#    u'following_url': u'https://api.github.com/users/jakevdp/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/jakevdp/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/jakevdp',
#    u'id': 781659,
#    u'login': u'jakevdp',
#    u'organizations_url': u'https://api.github.com/users/jakevdp/orgs',
#    u'received_events_url': u'https://api.github.com/users/jakevdp/received_events',
#    u'repos_url': u'https://api.github.com/users/jakevdp/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/jakevdp/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/jakevdp/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/jakevdp'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/pulls{/number}',
#   u'pushed_at': u'2017-02-02T21:23:39Z',
#   u'releases_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/releases{/id}',
#   u'size': 17069,
#   u'ssh_url': u'git@github.com:jakevdp/PythonDataScienceHandbook.git',
#   u'stargazers_count': 3521,
#   u'stargazers_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/subscription',
#   u'svn_url': u'https://github.com/jakevdp/PythonDataScienceHandbook',
#   u'tags_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/tags',
#   u'teams_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/teams',
#   u'trees_url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/git/trees{/sha}',
#   u'updated_at': u'2017-02-16T05:32:45Z',
#   u'url': u'https://api.github.com/repos/jakevdp/PythonDataScienceHandbook',
#   u'watchers': 3521,
#   u'watchers_count': 3521},
#  {u'archive_url': u'https://api.github.com/repos/vlandham/js_data/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/vlandham/js_data/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/vlandham/js_data/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/vlandham/js_data/branches{/branch}',
#   u'clone_url': u'https://github.com/vlandham/js_data.git',
#   u'collaborators_url': u'https://api.github.com/repos/vlandham/js_data/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/vlandham/js_data/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/vlandham/js_data/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/vlandham/js_data/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/vlandham/js_data/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/vlandham/js_data/contributors',
#   u'created_at': u'2015-03-02T04:05:09Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/vlandham/js_data/deployments',
#   u'description': u'Data manipulation and processing in JavaScript',
#   u'downloads_url': u'https://api.github.com/repos/vlandham/js_data/downloads',
#   u'events_url': u'https://api.github.com/repos/vlandham/js_data/events',
#   u'fork': False,
#   u'forks': 73,
#   u'forks_count': 73,
#   u'forks_url': u'https://api.github.com/repos/vlandham/js_data/forks',
#   u'full_name': u'vlandham/js_data',
#   u'git_commits_url': u'https://api.github.com/repos/vlandham/js_data/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/vlandham/js_data/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/vlandham/js_data/git/tags{/sha}',
#   u'git_url': u'git://github.com/vlandham/js_data.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': True,
#   u'has_wiki': True,
#   u'homepage': u'http://learnjsdata.com/',
#   u'hooks_url': u'https://api.github.com/repos/vlandham/js_data/hooks',
#   u'html_url': u'https://github.com/vlandham/js_data',
#   u'id': 31522833,
#   u'issue_comment_url': u'https://api.github.com/repos/vlandham/js_data/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/vlandham/js_data/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/vlandham/js_data/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/vlandham/js_data/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/vlandham/js_data/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/vlandham/js_data/languages',
#   u'merges_url': u'https://api.github.com/repos/vlandham/js_data/merges',
#   u'milestones_url': u'https://api.github.com/repos/vlandham/js_data/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'js_data',
#   u'notifications_url': u'https://api.github.com/repos/vlandham/js_data/notifications{?since,all,participating}',
#   u'open_issues': 8,
#   u'open_issues_count': 8,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/9369?v=3',
#    u'events_url': u'https://api.github.com/users/vlandham/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/vlandham/followers',
#    u'following_url': u'https://api.github.com/users/vlandham/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/vlandham/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/vlandham',
#    u'id': 9369,
#    u'login': u'vlandham',
#    u'organizations_url': u'https://api.github.com/users/vlandham/orgs',
#    u'received_events_url': u'https://api.github.com/users/vlandham/received_events',
#    u'repos_url': u'https://api.github.com/users/vlandham/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/vlandham/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/vlandham/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/vlandham'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/vlandham/js_data/pulls{/number}',
#   u'pushed_at': u'2016-02-22T16:03:24Z',
#   u'releases_url': u'https://api.github.com/repos/vlandham/js_data/releases{/id}',
#   u'size': 5488,
#   u'ssh_url': u'git@github.com:vlandham/js_data.git',
#   u'stargazers_count': 348,
#   u'stargazers_url': u'https://api.github.com/repos/vlandham/js_data/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/vlandham/js_data/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/vlandham/js_data/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/vlandham/js_data/subscription',
#   u'svn_url': u'https://github.com/vlandham/js_data',
#   u'tags_url': u'https://api.github.com/repos/vlandham/js_data/tags',
#   u'teams_url': u'https://api.github.com/repos/vlandham/js_data/teams',
#   u'trees_url': u'https://api.github.com/repos/vlandham/js_data/git/trees{/sha}',
#   u'updated_at': u'2017-02-14T21:33:16Z',
#   u'url': u'https://api.github.com/repos/vlandham/js_data',
#   u'watchers': 348,
#   u'watchers_count': 348},
#  {u'archive_url': u'https://api.github.com/repos/dunovank/jupyter-themes/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/dunovank/jupyter-themes/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/dunovank/jupyter-themes/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/dunovank/jupyter-themes/branches{/branch}',
#   u'clone_url': u'https://github.com/dunovank/jupyter-themes.git',
#   u'collaborators_url': u'https://api.github.com/repos/dunovank/jupyter-themes/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/dunovank/jupyter-themes/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/dunovank/jupyter-themes/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/dunovank/jupyter-themes/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/dunovank/jupyter-themes/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/dunovank/jupyter-themes/contributors',
#   u'created_at': u'2014-12-10T23:22:23Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/dunovank/jupyter-themes/deployments',
#   u'description': u'Custom Jupyter Notebook Themes',
#   u'downloads_url': u'https://api.github.com/repos/dunovank/jupyter-themes/downloads',
#   u'events_url': u'https://api.github.com/repos/dunovank/jupyter-themes/events',
#   u'fork': False,
#   u'forks': 103,
#   u'forks_count': 103,
#   u'forks_url': u'https://api.github.com/repos/dunovank/jupyter-themes/forks',
#   u'full_name': u'dunovank/jupyter-themes',
#   u'git_commits_url': u'https://api.github.com/repos/dunovank/jupyter-themes/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/dunovank/jupyter-themes/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/dunovank/jupyter-themes/git/tags{/sha}',
#   u'git_url': u'git://github.com/dunovank/jupyter-themes.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/dunovank/jupyter-themes/hooks',
#   u'html_url': u'https://github.com/dunovank/jupyter-themes',
#   u'id': 27844645,
#   u'issue_comment_url': u'https://api.github.com/repos/dunovank/jupyter-themes/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/dunovank/jupyter-themes/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/dunovank/jupyter-themes/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/dunovank/jupyter-themes/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/dunovank/jupyter-themes/labels{/name}',
#   u'language': u'CSS',
#   u'languages_url': u'https://api.github.com/repos/dunovank/jupyter-themes/languages',
#   u'merges_url': u'https://api.github.com/repos/dunovank/jupyter-themes/merges',
#   u'milestones_url': u'https://api.github.com/repos/dunovank/jupyter-themes/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'jupyter-themes',
#   u'notifications_url': u'https://api.github.com/repos/dunovank/jupyter-themes/notifications{?since,all,participating}',
#   u'open_issues': 24,
#   u'open_issues_count': 24,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/3844814?v=3',
#    u'events_url': u'https://api.github.com/users/dunovank/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/dunovank/followers',
#    u'following_url': u'https://api.github.com/users/dunovank/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/dunovank/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/dunovank',
#    u'id': 3844814,
#    u'login': u'dunovank',
#    u'organizations_url': u'https://api.github.com/users/dunovank/orgs',
#    u'received_events_url': u'https://api.github.com/users/dunovank/received_events',
#    u'repos_url': u'https://api.github.com/users/dunovank/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/dunovank/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/dunovank/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/dunovank'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/dunovank/jupyter-themes/pulls{/number}',
#   u'pushed_at': u'2017-02-08T04:58:19Z',
#   u'releases_url': u'https://api.github.com/repos/dunovank/jupyter-themes/releases{/id}',
#   u'size': 38244,
#   u'ssh_url': u'git@github.com:dunovank/jupyter-themes.git',
#   u'stargazers_count': 1308,
#   u'stargazers_url': u'https://api.github.com/repos/dunovank/jupyter-themes/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/dunovank/jupyter-themes/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/dunovank/jupyter-themes/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/dunovank/jupyter-themes/subscription',
#   u'svn_url': u'https://github.com/dunovank/jupyter-themes',
#   u'tags_url': u'https://api.github.com/repos/dunovank/jupyter-themes/tags',
#   u'teams_url': u'https://api.github.com/repos/dunovank/jupyter-themes/teams',
#   u'trees_url': u'https://api.github.com/repos/dunovank/jupyter-themes/git/trees{/sha}',
#   u'updated_at': u'2017-02-15T21:45:18Z',
#   u'url': u'https://api.github.com/repos/dunovank/jupyter-themes',
#   u'watchers': 1308,
#   u'watchers_count': 1308},
#  {u'archive_url': u'https://api.github.com/repos/translate/pootle/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/translate/pootle/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/translate/pootle/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/translate/pootle/branches{/branch}',
#   u'clone_url': u'https://github.com/translate/pootle.git',
#   u'collaborators_url': u'https://api.github.com/repos/translate/pootle/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/translate/pootle/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/translate/pootle/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/translate/pootle/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/translate/pootle/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/translate/pootle/contributors',
#   u'created_at': u'2012-03-19T23:06:03Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/translate/pootle/deployments',
#   u'description': u'Online translation tool',
#   u'downloads_url': u'https://api.github.com/repos/translate/pootle/downloads',
#   u'events_url': u'https://api.github.com/repos/translate/pootle/events',
#   u'fork': False,
#   u'forks': 218,
#   u'forks_count': 218,
#   u'forks_url': u'https://api.github.com/repos/translate/pootle/forks',
#   u'full_name': u'translate/pootle',
#   u'git_commits_url': u'https://api.github.com/repos/translate/pootle/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/translate/pootle/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/translate/pootle/git/tags{/sha}',
#   u'git_url': u'git://github.com/translate/pootle.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': True,
#   u'has_wiki': True,
#   u'homepage': u'http://pootle.translatehouse.org',
#   u'hooks_url': u'https://api.github.com/repos/translate/pootle/hooks',
#   u'html_url': u'https://github.com/translate/pootle',
#   u'id': 3769702,
#   u'issue_comment_url': u'https://api.github.com/repos/translate/pootle/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/translate/pootle/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/translate/pootle/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/translate/pootle/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/translate/pootle/labels{/name}',
#   u'language': u'Python',
#   u'languages_url': u'https://api.github.com/repos/translate/pootle/languages',
#   u'merges_url': u'https://api.github.com/repos/translate/pootle/merges',
#   u'milestones_url': u'https://api.github.com/repos/translate/pootle/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'pootle',
#   u'notifications_url': u'https://api.github.com/repos/translate/pootle/notifications{?since,all,participating}',
#   u'open_issues': 478,
#   u'open_issues_count': 478,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1538178?v=3',
#    u'events_url': u'https://api.github.com/users/translate/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/translate/followers',
#    u'following_url': u'https://api.github.com/users/translate/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/translate/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/translate',
#    u'id': 1538178,
#    u'login': u'translate',
#    u'organizations_url': u'https://api.github.com/users/translate/orgs',
#    u'received_events_url': u'https://api.github.com/users/translate/received_events',
#    u'repos_url': u'https://api.github.com/users/translate/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/translate/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/translate/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/translate'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/translate/pootle/pulls{/number}',
#   u'pushed_at': u'2017-02-15T22:46:33Z',
#   u'releases_url': u'https://api.github.com/repos/translate/pootle/releases{/id}',
#   u'size': 112388,
#   u'ssh_url': u'git@github.com:translate/pootle.git',
#   u'stargazers_count': 800,
#   u'stargazers_url': u'https://api.github.com/repos/translate/pootle/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/translate/pootle/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/translate/pootle/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/translate/pootle/subscription',
#   u'svn_url': u'https://github.com/translate/pootle',
#   u'tags_url': u'https://api.github.com/repos/translate/pootle/tags',
#   u'teams_url': u'https://api.github.com/repos/translate/pootle/teams',
#   u'trees_url': u'https://api.github.com/repos/translate/pootle/git/trees{/sha}',
#   u'updated_at': u'2017-02-15T14:35:21Z',
#   u'url': u'https://api.github.com/repos/translate/pootle',
#   u'watchers': 800,
#   u'watchers_count': 800},
#  {u'archive_url': u'https://api.github.com/repos/anthonynsimon/parrot/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/anthonynsimon/parrot/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/anthonynsimon/parrot/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/anthonynsimon/parrot/branches{/branch}',
#   u'clone_url': u'https://github.com/anthonynsimon/parrot.git',
#   u'collaborators_url': u'https://api.github.com/repos/anthonynsimon/parrot/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/anthonynsimon/parrot/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/anthonynsimon/parrot/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/anthonynsimon/parrot/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/anthonynsimon/parrot/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/anthonynsimon/parrot/contributors',
#   u'created_at': u'2016-11-03T22:23:11Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/anthonynsimon/parrot/deployments',
#   u'description': u'Self-hosted Localization Management Platform built with Go and Angular 2',
#   u'downloads_url': u'https://api.github.com/repos/anthonynsimon/parrot/downloads',
#   u'events_url': u'https://api.github.com/repos/anthonynsimon/parrot/events',
#   u'fork': False,
#   u'forks': 29,
#   u'forks_count': 29,
#   u'forks_url': u'https://api.github.com/repos/anthonynsimon/parrot/forks',
#   u'full_name': u'anthonynsimon/parrot',
#   u'git_commits_url': u'https://api.github.com/repos/anthonynsimon/parrot/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/anthonynsimon/parrot/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/anthonynsimon/parrot/git/tags{/sha}',
#   u'git_url': u'git://github.com/anthonynsimon/parrot.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': u'http://anthonynsimon.com/parrot.github.io/',
#   u'hooks_url': u'https://api.github.com/repos/anthonynsimon/parrot/hooks',
#   u'html_url': u'https://github.com/anthonynsimon/parrot',
#   u'id': 72792222,
#   u'issue_comment_url': u'https://api.github.com/repos/anthonynsimon/parrot/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/anthonynsimon/parrot/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/anthonynsimon/parrot/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/anthonynsimon/parrot/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/anthonynsimon/parrot/labels{/name}',
#   u'language': u'Go',
#   u'languages_url': u'https://api.github.com/repos/anthonynsimon/parrot/languages',
#   u'merges_url': u'https://api.github.com/repos/anthonynsimon/parrot/merges',
#   u'milestones_url': u'https://api.github.com/repos/anthonynsimon/parrot/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'parrot',
#   u'notifications_url': u'https://api.github.com/repos/anthonynsimon/parrot/notifications{?since,all,participating}',
#   u'open_issues': 23,
#   u'open_issues_count': 23,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/13251079?v=3',
#    u'events_url': u'https://api.github.com/users/anthonynsimon/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/anthonynsimon/followers',
#    u'following_url': u'https://api.github.com/users/anthonynsimon/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/anthonynsimon/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/anthonynsimon',
#    u'id': 13251079,
#    u'login': u'anthonynsimon',
#    u'organizations_url': u'https://api.github.com/users/anthonynsimon/orgs',
#    u'received_events_url': u'https://api.github.com/users/anthonynsimon/received_events',
#    u'repos_url': u'https://api.github.com/users/anthonynsimon/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/anthonynsimon/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/anthonynsimon/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/anthonynsimon'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/anthonynsimon/parrot/pulls{/number}',
#   u'pushed_at': u'2017-02-02T15:11:34Z',
#   u'releases_url': u'https://api.github.com/repos/anthonynsimon/parrot/releases{/id}',
#   u'size': 1733,
#   u'ssh_url': u'git@github.com:anthonynsimon/parrot.git',
#   u'stargazers_count': 745,
#   u'stargazers_url': u'https://api.github.com/repos/anthonynsimon/parrot/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/anthonynsimon/parrot/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/anthonynsimon/parrot/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/anthonynsimon/parrot/subscription',
#   u'svn_url': u'https://github.com/anthonynsimon/parrot',
#   u'tags_url': u'https://api.github.com/repos/anthonynsimon/parrot/tags',
#   u'teams_url': u'https://api.github.com/repos/anthonynsimon/parrot/teams',
#   u'trees_url': u'https://api.github.com/repos/anthonynsimon/parrot/git/trees{/sha}',
#   u'updated_at': u'2017-02-16T05:51:18Z',
#   u'url': u'https://api.github.com/repos/anthonynsimon/parrot',
#   u'watchers': 745,
#   u'watchers_count': 745},
#  {u'archive_url': u'https://api.github.com/repos/42wim/matterbridge/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/42wim/matterbridge/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/42wim/matterbridge/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/42wim/matterbridge/branches{/branch}',
#   u'clone_url': u'https://github.com/42wim/matterbridge.git',
#   u'collaborators_url': u'https://api.github.com/repos/42wim/matterbridge/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/42wim/matterbridge/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/42wim/matterbridge/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/42wim/matterbridge/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/42wim/matterbridge/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/42wim/matterbridge/contributors',
#   u'created_at': u'2015-10-23T15:07:05Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/42wim/matterbridge/deployments',
#   u'description': u'bridge between mattermost, IRC, gitter, xmpp, slack, discord, telegram, rocket.chat and hipchat (via xmpp)',
#   u'downloads_url': u'https://api.github.com/repos/42wim/matterbridge/downloads',
#   u'events_url': u'https://api.github.com/repos/42wim/matterbridge/events',
#   u'fork': False,
#   u'forks': 32,
#   u'forks_count': 32,
#   u'forks_url': u'https://api.github.com/repos/42wim/matterbridge/forks',
#   u'full_name': u'42wim/matterbridge',
#   u'git_commits_url': u'https://api.github.com/repos/42wim/matterbridge/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/42wim/matterbridge/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/42wim/matterbridge/git/tags{/sha}',
#   u'git_url': u'git://github.com/42wim/matterbridge.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/42wim/matterbridge/hooks',
#   u'html_url': u'https://github.com/42wim/matterbridge',
#   u'id': 44820350,
#   u'issue_comment_url': u'https://api.github.com/repos/42wim/matterbridge/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/42wim/matterbridge/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/42wim/matterbridge/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/42wim/matterbridge/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/42wim/matterbridge/labels{/name}',
#   u'language': u'Go',
#   u'languages_url': u'https://api.github.com/repos/42wim/matterbridge/languages',
#   u'merges_url': u'https://api.github.com/repos/42wim/matterbridge/merges',
#   u'milestones_url': u'https://api.github.com/repos/42wim/matterbridge/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'matterbridge',
#   u'notifications_url': u'https://api.github.com/repos/42wim/matterbridge/notifications{?since,all,participating}',
#   u'open_issues': 16,
#   u'open_issues_count': 16,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1810977?v=3',
#    u'events_url': u'https://api.github.com/users/42wim/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/42wim/followers',
#    u'following_url': u'https://api.github.com/users/42wim/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/42wim/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/42wim',
#    u'id': 1810977,
#    u'login': u'42wim',
#    u'organizations_url': u'https://api.github.com/users/42wim/orgs',
#    u'received_events_url': u'https://api.github.com/users/42wim/received_events',
#    u'repos_url': u'https://api.github.com/users/42wim/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/42wim/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/42wim/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/42wim'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/42wim/matterbridge/pulls{/number}',
#   u'pushed_at': u'2017-02-14T22:52:53Z',
#   u'releases_url': u'https://api.github.com/repos/42wim/matterbridge/releases{/id}',
#   u'size': 826,
#   u'ssh_url': u'git@github.com:42wim/matterbridge.git',
#   u'stargazers_count': 161,
#   u'stargazers_url': u'https://api.github.com/repos/42wim/matterbridge/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/42wim/matterbridge/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/42wim/matterbridge/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/42wim/matterbridge/subscription',
#   u'svn_url': u'https://github.com/42wim/matterbridge',
#   u'tags_url': u'https://api.github.com/repos/42wim/matterbridge/tags',
#   u'teams_url': u'https://api.github.com/repos/42wim/matterbridge/teams',
#   u'trees_url': u'https://api.github.com/repos/42wim/matterbridge/git/trees{/sha}',
#   u'updated_at': u'2017-02-15T08:18:40Z',
#   u'url': u'https://api.github.com/repos/42wim/matterbridge',
#   u'watchers': 161,
#   u'watchers_count': 161},
#  {u'archive_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/branches{/branch}',
#   u'clone_url': u'https://github.com/mattermost/mattermost-driver-javascript.git',
#   u'collaborators_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/contributors',
#   u'created_at': u'2016-05-13T13:51:25Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/deployments',
#   u'description': u'Javascript library for interacting with the Mattermost API',
#   u'downloads_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/downloads',
#   u'events_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/events',
#   u'fork': False,
#   u'forks': 23,
#   u'forks_count': 23,
#   u'forks_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/forks',
#   u'full_name': u'mattermost/mattermost-driver-javascript',
#   u'git_commits_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/git/tags{/sha}',
#   u'git_url': u'git://github.com/mattermost/mattermost-driver-javascript.git',
#   u'has_downloads': True,
#   u'has_issues': False,
#   u'has_pages': False,
#   u'has_wiki': False,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/hooks',
#   u'html_url': u'https://github.com/mattermost/mattermost-driver-javascript',
#   u'id': 58744418,
#   u'issue_comment_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/languages',
#   u'merges_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/merges',
#   u'milestones_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'mattermost-driver-javascript',
#   u'notifications_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/notifications{?since,all,participating}',
#   u'open_issues': 0,
#   u'open_issues_count': 0,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/9828093?v=3',
#    u'events_url': u'https://api.github.com/users/mattermost/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/mattermost/followers',
#    u'following_url': u'https://api.github.com/users/mattermost/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/mattermost/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/mattermost',
#    u'id': 9828093,
#    u'login': u'mattermost',
#    u'organizations_url': u'https://api.github.com/users/mattermost/orgs',
#    u'received_events_url': u'https://api.github.com/users/mattermost/received_events',
#    u'repos_url': u'https://api.github.com/users/mattermost/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/mattermost/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/mattermost/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/mattermost'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/pulls{/number}',
#   u'pushed_at': u'2017-02-13T20:38:58Z',
#   u'releases_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/releases{/id}',
#   u'size': 95,
#   u'ssh_url': u'git@github.com:mattermost/mattermost-driver-javascript.git',
#   u'stargazers_count': 30,
#   u'stargazers_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/mattermost/mattermost-driver-javascript/subscribers',
# ...
#   u'svn_url': u'https://github.com/aaren/notedown',
#   u'tags_url': u'https://api.github.com/repos/aaren/notedown/tags',
#   u'teams_url': u'https://api.github.com/repos/aaren/notedown/teams',
#   u'trees_url': u'https://api.github.com/repos/aaren/notedown/git/trees{/sha}',
#   u'updated_at': u'2017-02-14T14:36:51Z',
#   u'url': u'https://api.github.com/repos/aaren/notedown',
#   u'watchers': 270,
#   u'watchers_count': 270},
#  {u'archive_url': u'https://api.github.com/repos/concourse/concourse/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/concourse/concourse/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/concourse/concourse/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/concourse/concourse/branches{/branch}',
#   u'clone_url': u'https://github.com/concourse/concourse.git',
#   u'collaborators_url': u'https://api.github.com/repos/concourse/concourse/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/concourse/concourse/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/concourse/concourse/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/concourse/concourse/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/concourse/concourse/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/concourse/concourse/contributors',
#   u'created_at': u'2014-04-19T20:45:45Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/concourse/concourse/deployments',
#   u'description': u'BOSH Release',
#   u'downloads_url': u'https://api.github.com/repos/concourse/concourse/downloads',
#   u'events_url': u'https://api.github.com/repos/concourse/concourse/events',
#   u'fork': False,
#   u'forks': 221,
#   u'forks_count': 221,
#   u'forks_url': u'https://api.github.com/repos/concourse/concourse/forks',
#   u'full_name': u'concourse/concourse',
#   u'git_commits_url': u'https://api.github.com/repos/concourse/concourse/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/concourse/concourse/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/concourse/concourse/git/tags{/sha}',
#   u'git_url': u'git://github.com/concourse/concourse.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': False,
#   u'homepage': u'https://concourse.ci',
#   u'hooks_url': u'https://api.github.com/repos/concourse/concourse/hooks',
#   u'html_url': u'https://github.com/concourse/concourse',
#   u'id': 18950460,
#   u'issue_comment_url': u'https://api.github.com/repos/concourse/concourse/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/concourse/concourse/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/concourse/concourse/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/concourse/concourse/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/concourse/concourse/labels{/name}',
#   u'language': u'Go',
#   u'languages_url': u'https://api.github.com/repos/concourse/concourse/languages',
#   u'merges_url': u'https://api.github.com/repos/concourse/concourse/merges',
#   u'milestones_url': u'https://api.github.com/repos/concourse/concourse/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'concourse',
#   u'notifications_url': u'https://api.github.com/repos/concourse/concourse/notifications{?since,all,participating}',
#   u'open_issues': 298,
#   u'open_issues_count': 298,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/7809479?v=3',
#    u'events_url': u'https://api.github.com/users/concourse/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/concourse/followers',
#    u'following_url': u'https://api.github.com/users/concourse/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/concourse/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/concourse',
#    u'id': 7809479,
#    u'login': u'concourse',
#    u'organizations_url': u'https://api.github.com/users/concourse/orgs',
#    u'received_events_url': u'https://api.github.com/users/concourse/received_events',
#    u'repos_url': u'https://api.github.com/users/concourse/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/concourse/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/concourse/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/concourse'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/concourse/concourse/pulls{/number}',
#   u'pushed_at': u'2017-02-16T00:14:21Z',
#   u'releases_url': u'https://api.github.com/repos/concourse/concourse/releases{/id}',
#   u'size': 8158,
#   u'ssh_url': u'git@github.com:concourse/concourse.git',
#   u'stargazers_count': 1354,
#   u'stargazers_url': u'https://api.github.com/repos/concourse/concourse/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/concourse/concourse/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/concourse/concourse/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/concourse/concourse/subscription',
#   u'svn_url': u'https://github.com/concourse/concourse',
#   u'tags_url': u'https://api.github.com/repos/concourse/concourse/tags',
#   u'teams_url': u'https://api.github.com/repos/concourse/concourse/teams',
#   u'trees_url': u'https://api.github.com/repos/concourse/concourse/git/trees{/sha}',
#   u'updated_at': u'2017-02-16T05:16:07Z',
#   u'url': u'https://api.github.com/repos/concourse/concourse',
#   u'watchers': 1354,
#   u'watchers_count': 1354},
#  {u'archive_url': u'https://api.github.com/repos/adamcooke/staytus/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/adamcooke/staytus/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/adamcooke/staytus/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/adamcooke/staytus/branches{/branch}',
#   u'clone_url': u'https://github.com/adamcooke/staytus.git',
#   u'collaborators_url': u'https://api.github.com/repos/adamcooke/staytus/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/adamcooke/staytus/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/adamcooke/staytus/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/adamcooke/staytus/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/adamcooke/staytus/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/adamcooke/staytus/contributors',
#   u'created_at': u'2015-02-19T21:34:14Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/adamcooke/staytus/deployments',
#   u'description': u'An open source solution for publishing the status of your services',
#   u'downloads_url': u'https://api.github.com/repos/adamcooke/staytus/downloads',
#   u'events_url': u'https://api.github.com/repos/adamcooke/staytus/events',
#   u'fork': False,
#   u'forks': 91,
#   u'forks_count': 91,
#   u'forks_url': u'https://api.github.com/repos/adamcooke/staytus/forks',
#   u'full_name': u'adamcooke/staytus',
#   u'git_commits_url': u'https://api.github.com/repos/adamcooke/staytus/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/adamcooke/staytus/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/adamcooke/staytus/git/tags{/sha}',
#   u'git_url': u'git://github.com/adamcooke/staytus.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': False,
#   u'homepage': u'http://staytus.co',
#   u'hooks_url': u'https://api.github.com/repos/adamcooke/staytus/hooks',
#   u'html_url': u'https://github.com/adamcooke/staytus',
#   u'id': 31038096,
#   u'issue_comment_url': u'https://api.github.com/repos/adamcooke/staytus/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/adamcooke/staytus/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/adamcooke/staytus/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/adamcooke/staytus/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/adamcooke/staytus/labels{/name}',
#   u'language': u'Ruby',
#   u'languages_url': u'https://api.github.com/repos/adamcooke/staytus/languages',
#   u'merges_url': u'https://api.github.com/repos/adamcooke/staytus/merges',
#   u'milestones_url': u'https://api.github.com/repos/adamcooke/staytus/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'staytus',
#   u'notifications_url': u'https://api.github.com/repos/adamcooke/staytus/notifications{?since,all,participating}',
#   u'open_issues': 31,
#   u'open_issues_count': 31,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/4765?v=3',
#    u'events_url': u'https://api.github.com/users/adamcooke/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/adamcooke/followers',
#    u'following_url': u'https://api.github.com/users/adamcooke/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/adamcooke/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/adamcooke',
#    u'id': 4765,
#    u'login': u'adamcooke',
#    u'organizations_url': u'https://api.github.com/users/adamcooke/orgs',
#    u'received_events_url': u'https://api.github.com/users/adamcooke/received_events',
#    u'repos_url': u'https://api.github.com/users/adamcooke/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/adamcooke/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/adamcooke/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/adamcooke'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/adamcooke/staytus/pulls{/number}',
#   u'pushed_at': u'2017-01-03T19:07:33Z',
#   u'releases_url': u'https://api.github.com/repos/adamcooke/staytus/releases{/id}',
#   u'size': 529,
#   u'ssh_url': u'git@github.com:adamcooke/staytus.git',
#   u'stargazers_count': 574,
#   u'stargazers_url': u'https://api.github.com/repos/adamcooke/staytus/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/adamcooke/staytus/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/adamcooke/staytus/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/adamcooke/staytus/subscription',
#   u'svn_url': u'https://github.com/adamcooke/staytus',
#   u'tags_url': u'https://api.github.com/repos/adamcooke/staytus/tags',
#   u'teams_url': u'https://api.github.com/repos/adamcooke/staytus/teams',
#   u'trees_url': u'https://api.github.com/repos/adamcooke/staytus/git/trees{/sha}',
#   u'updated_at': u'2017-02-15T22:36:38Z',
#   u'url': u'https://api.github.com/repos/adamcooke/staytus',
#   u'watchers': 574,
#   u'watchers_count': 574},
#  {u'archive_url': u'https://api.github.com/repos/yarnpkg/yarn/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/yarnpkg/yarn/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/yarnpkg/yarn/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/yarnpkg/yarn/branches{/branch}',
#   u'clone_url': u'https://github.com/yarnpkg/yarn.git',
#   u'collaborators_url': u'https://api.github.com/repos/yarnpkg/yarn/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/yarnpkg/yarn/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/yarnpkg/yarn/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/yarnpkg/yarn/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/yarnpkg/yarn/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/yarnpkg/yarn/contributors',
#   u'created_at': u'2016-01-19T17:39:16Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/yarnpkg/yarn/deployments',
#   u'description': u'\U0001f4e6\U0001f408 Fast, reliable, and secure dependency management.',
#   u'downloads_url': u'https://api.github.com/repos/yarnpkg/yarn/downloads',
#   u'events_url': u'https://api.github.com/repos/yarnpkg/yarn/events',
#   u'fork': False,
#   u'forks': 915,
#   u'forks_count': 915,
#   u'forks_url': u'https://api.github.com/repos/yarnpkg/yarn/forks',
#   u'full_name': u'yarnpkg/yarn',
#   u'git_commits_url': u'https://api.github.com/repos/yarnpkg/yarn/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/yarnpkg/yarn/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/yarnpkg/yarn/git/tags{/sha}',
#   u'git_url': u'git://github.com/yarnpkg/yarn.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': False,
#   u'homepage': u'https://yarnpkg.com',
#   u'hooks_url': u'https://api.github.com/repos/yarnpkg/yarn/hooks',
#   u'html_url': u'https://github.com/yarnpkg/yarn',
#   u'id': 49970642,
#   u'issue_comment_url': u'https://api.github.com/repos/yarnpkg/yarn/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/yarnpkg/yarn/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/yarnpkg/yarn/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/yarnpkg/yarn/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/yarnpkg/yarn/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/yarnpkg/yarn/languages',
#   u'merges_url': u'https://api.github.com/repos/yarnpkg/yarn/merges',
#   u'milestones_url': u'https://api.github.com/repos/yarnpkg/yarn/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'yarn',
#   u'notifications_url': u'https://api.github.com/repos/yarnpkg/yarn/notifications{?since,all,participating}',
#   u'open_issues': 694,
#   u'open_issues_count': 694,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/22247014?v=3',
#    u'events_url': u'https://api.github.com/users/yarnpkg/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/yarnpkg/followers',
#    u'following_url': u'https://api.github.com/users/yarnpkg/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/yarnpkg/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/yarnpkg',
#    u'id': 22247014,
#    u'login': u'yarnpkg',
#    u'organizations_url': u'https://api.github.com/users/yarnpkg/orgs',
#    u'received_events_url': u'https://api.github.com/users/yarnpkg/received_events',
#    u'repos_url': u'https://api.github.com/users/yarnpkg/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/yarnpkg/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/yarnpkg/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/yarnpkg'},
#   u'permissions': {u'admin': False, u'pull': True, u'push': False},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/yarnpkg/yarn/pulls{/number}',
#   u'pushed_at': u'2017-02-15T16:10:06Z',
#   u'releases_url': u'https://api.github.com/repos/yarnpkg/yarn/releases{/id}',
#   u'size': 48134,
#   u'ssh_url': u'git@github.com:yarnpkg/yarn.git',
#   u'stargazers_count': 22597,
#   u'stargazers_url': u'https://api.github.com/repos/yarnpkg/yarn/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/yarnpkg/yarn/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/yarnpkg/yarn/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/yarnpkg/yarn/subscription',
#   u'svn_url': u'https://github.com/yarnpkg/yarn',
#   u'tags_url': u'https://api.github.com/repos/yarnpkg/yarn/tags',
#   u'teams_url': u'https://api.github.com/repos/yarnpkg/yarn/teams',
#   u'trees_url': u'https://api.github.com/repos/yarnpkg/yarn/git/trees{/sha}',
#   u'updated_at': u'2017-02-16T06:22:16Z',
#   u'url': u'https://api.github.com/repos/yarnpkg/yarn',
#   u'watchers': 22597,
#   u'watchers_count': 22597}]

# %% [markdown]
# ## User-level Endpoints
#
# If we want to get information about us (the person who created the access token), we can do so using `https://api.github.com/user` instead of typing in our own user path

# %%
response = requests.get("https://api.github.com/user", headers = headers)
js = response.json()
print js
print "\n"
print js.keys()
# Out:
# {u'disk_usage': 154576, u'private_gists': 0, u'public_repos': 22, u'site_admin': False, u'subscriptions_url': u'https://api.github.com/users/jwilber/subscriptions', u'gravatar_id': u'', u'hireable': None, u'id': 8595819, u'followers_url': u'https://api.github.com/users/jwilber/followers', u'following_url': u'https://api.github.com/users/jwilber/following{/other_user}', u'collaborators': 4, u'total_private_repos': 2, u'blog': None, u'followers': 2, u'location': u'Berkeley/San Diego', u'type': u'User', u'email': None, u'bio': u'I enjoy statistics, data science, machine learning, surfing, and fitness. I use R and Python.', u'gists_url': u'https://api.github.com/users/jwilber/gists{/gist_id}', u'owned_private_repos': 2, u'company': None, u'events_url': u'https://api.github.com/users/jwilber/events{/privacy}', u'html_url': u'https://github.com/jwilber', u'updated_at': u'2017-01-19T05:49:43Z', u'plan': {u'collaborators': 0, u'name': u'personal', u'private_repos': 9999, u'space': 976562499}, u'received_events_url': u'https://api.github.com/users/jwilber/received_events', u'starred_url': u'https://api.github.com/users/jwilber/starred{/owner}{/repo}', u'public_gists': 0, u'name': u'Jared Wilber', u'organizations_url': u'https://api.github.com/users/jwilber/orgs', u'url': u'https://api.github.com/users/jwilber', u'created_at': u'2014-08-30T01:52:33Z', u'avatar_url': u'https://avatars.githubusercontent.com/u/8595819?v=3', u'repos_url': u'https://api.github.com/users/jwilber/repos', u'following': 2, u'login': u'jwilber', u'two_factor_authentication': False}
#
#
# [u'disk_usage', u'private_gists', u'public_repos', u'site_admin', u'subscriptions_url', u'gravatar_id', u'hireable', u'id', u'followers_url', u'following_url', u'collaborators', u'total_private_repos', u'blog', u'followers', u'location', u'type', u'email', u'bio', u'gists_url', u'owned_private_repos', u'company', u'events_url', u'html_url', u'updated_at', u'plan', u'received_events_url', u'starred_url', u'public_gists', u'name', u'organizations_url', u'url', u'created_at', u'avatar_url', u'repos_url', u'following', u'login', u'two_factor_authentication']

# %%
print js["bio"]
# Out:
# I enjoy statistics, data science, machine learning, surfing, and fitness. I use R and Python.

# %% [markdown]
# ## Post Requests
#
# We keep making **get** requests to the api server. However, we can make other requests as well.
#
#
# We can use **post** requests to send information to the server. With the github api, we can do this to create new repositories. In my opinion this is kind of excessive since git is already integrated so well with the commandline, but this exists. The more you know etc.

# %%
# The following will create a repo named test

# payload = {"name": "test"}
# requests.post("https://api.github.com/user/repos", json=payload)

# %% [markdown]
# More request types exist. E.g.:
#
# ### Put Requests: send the complete object we're revising as a replacement for the server's existing version.
#
# ### Patch Requests: change a few attributes of an object, but don't want to resend the entire object to the server
#
# ### Delete Requests: delete repos
